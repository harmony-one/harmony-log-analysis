# %% [markdown]
# # Log Analysis and Visulization

# %%
import utils
import os
from os import path
import datetime
import pandas as pd

# %% [markdown]
# # Result
#
# - Statistics Summary
#     - transaction per second
#     - time per block
#     - size
#     - gas
#
#
# - Features vs Time / Block Height (with all shards / per shard)
#     - staking transaction per second
#     - total transaction per second
#     - transaction per second
#     - time per block
#     - size
#     - gas

# %%
if __name__ == "__main__":
    
    date = datetime.date.today()-datetime.timedelta(days=1)
    name = "ostn_"+date.strftime("%Y_%m_%d")
    fig_dir = "../../graphs/test_logs/ostn/" + date.strftime("%Y_%m_%d") + "/"
    log_dir = "/home/ubuntu/jupyter/monitor/mini_explorer/data/" + name
    html_dir = "../../docs/graphs/test_logs/ostn/" + date.strftime("%Y_%m_%d") + "/"

    data = [html_dir, fig_dir]
    for directory in data:
        if not path.exists(directory):
            try:
                os.makedirs(directory)
            except:
                print("Could not make directory")
                exit(1)

    data = utils.read_data(log_dir)
    shard = utils.data_processing(data)
    
    utils.set_config({
        'ignore_printing_statistics_summary': False,
        'ignore_drawing_features_vs_time_per_shard' : True,
        'ignore_drawing_features_vs_block_per_shard' : True,
        'ignore_drawing_staking_features_vs_time_per_shard' : True,
        'ignore_drawing_staking_features_vs_block_per_shard' : True,
        'ignore_drawing_features_vs_time' : False,
        'ignore_drawing_features_vs_block' : True
    })
    
    config = utils.config
    ## get the index of the new chain started
    index = []
    for s in shard:
        i = s[s['time_per_block'] < 0].index.tolist()   
        if len(i) == 0:
            break
        i.insert(0,0)
        i.append(len(s))
        index.append(i)
    
    if len(index) == 0:
        new = pd.concat(shard)
        new.reset_index(inplace = True, drop = True)
        print("transaction for ", date, new['transactions'].sum())
        utils.visualization(new, fig_dir, html_dir, config)
    else:    
        for i in range(len(index[0])-1):
            df = []
            for s in range(len(shard)):
                df.append(shard[s].iloc[index[s][i]+1:index[s][i+1]])
            new = pd.concat(df)

            fig_path = fig_dir + "chain_" + str(i) + "/"
            if not os.path.exists(fig_path):
                os.makedirs(fig_path)

            utils.visualization(new, fig_path, html_dir, config)
# Out:
# Statistics summary for shard 0
# ==================================
# Total data points: 1726
#                size           gas  transaction_per_second  time_per_block
# mean   18549.128042  3.958382e+06                0.089810       12.845834
# std    63959.423315  1.522158e+07                0.665357       14.436542
# min      688.000000  0.000000e+00                0.000000        8.000000
# 25%     1002.000000  0.000000e+00                0.000000        8.000000
# 50%     1156.000000  0.000000e+00                0.000000        9.000000
# 75%     1309.000000  0.000000e+00                0.000000       11.000000
# max   360165.000000  8.051802e+07               16.888889      251.000000
#
# Features vs UTC Time Graphs for shard 0
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_staking_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_total_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_time_per_block_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_size_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_gas_vs_utc_time.html
#
# Features vs Block Height Graphs for shard 0
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_staking_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_total_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_time_per_block_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_size_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_gas_vs_block_height.html
#
# Staking Features vs UTC Time Graphs for shard 0
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_staking_info_vs_time.html
#
# Staking Features vs Block Height Graphs for shard 0
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_0_staking_info_vs_block.html
#
# Statistics summary for shard 1
# ==================================
# Total data points: 2257
#               size           gas  transaction_per_second  time_per_block
# mean   1188.006646  2.381923e+04                0.114310        10.02603
# std    3728.982198  1.740051e+05                0.836640         1.34535
# min     688.000000  0.000000e+00                0.000000         9.00000
# 25%     688.000000  0.000000e+00                0.000000        10.00000
# 50%     688.000000  0.000000e+00                0.000000        10.00000
# 75%     688.000000  0.000000e+00                0.000000        10.00000
# max   39745.000000  1.953000e+06               10.333333        20.00000
#
# Features vs UTC Time Graphs for shard 1
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_time_per_block_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_size_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_gas_vs_utc_time.html
#
# Features vs Block Height Graphs for shard 1
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_time_per_block_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_size_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_1_gas_vs_block_height.html
#
# Statistics summary for shard 2
# ==================================
# Total data points: 793
#               size  gas  transaction_per_second  time_per_block
# mean    909.638083  0.0                     0.0       10.355599
# std    2784.016870  0.0                     0.0        1.409187
# min     688.000000  0.0                     0.0        8.000000
# 25%     688.000000  0.0                     0.0       10.000000
# 50%     688.000000  0.0                     0.0       10.000000
# 75%     688.000000  0.0                     0.0       10.000000
# max   35856.000000  0.0                     0.0       21.000000
#
# Features vs UTC Time Graphs for shard 2
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_time_per_block_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_size_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_gas_vs_utc_time.html
#
# Features vs Block Height Graphs for shard 2
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_time_per_block_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_size_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_2_gas_vs_block_height.html
#
# Statistics summary for shard 3
# ==================================
# Total data points: 2209
#               size  gas  transaction_per_second  time_per_block
# mean   1070.087823  0.0                     0.0       10.255495
# std    3646.547414  0.0                     0.0        1.290096
# min     688.000000  0.0                     0.0        9.000000
# 25%     688.000000  0.0                     0.0       10.000000
# 50%     688.000000  0.0                     0.0       10.000000
# 75%     688.000000  0.0                     0.0       10.000000
# max   35947.000000  0.0                     0.0       20.000000
#
# Features vs UTC Time Graphs for shard 3
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_transaction_per_second_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_time_per_block_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_size_vs_utc_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_gas_vs_utc_time.html
#
# Features vs Block Height Graphs for shard 3
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_time_per_block_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_size_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/shard_3_gas_vs_block_height.html
#
# Features vs Time
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/staking_transaction_per_second_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/total_transaction_per_second_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/transaction_per_second_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/time_per_block_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/size_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/gas_vs_time.html
#
# Features vs Block Height
# PNG saved in ../../graphs/test_logs/stress_test_03_11/
# ==================================
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/staking_transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/total_transaction_per_second_vs_time.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/transaction_per_second_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/time_per_block_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/size_vs_block_height.html
# HTML saved in https://harmony-one.github.io/harmony-log-analysis/graphs/test_logs/stress_test_03_11/gas_vs_block_height.html
