# %%
import json
import pandas as pd
import numpy as np
import csv
import re

# %%
df = pd.read_csv('json/angels-20200702', delimiter=r"\s+", header = None, error_bad_lines=False,names = ['#followe_by_team', 'retweet_count','favorite_count','tweet_created_at','followers_count','friends_count','followers_count/friends_count+1','statuses_count','favorites_count','id','account_created_at','screen_name','name', 'url', 'url_2', 'url_3', 'url_4', 'url_5', 'url_6'])

# %% [markdown]
# ## merge the urls

# %%
pattern = re.compile('.*?\/#.*?=one.*?')
column = ['url', 'url_2', 'url_3', 'url_4', 'url_5', 'url_6']
for url in column:
    df[url] = df[url].apply(lambda c: c if type(c) == str and re.match(pattern, c) else np.nan)
    
df['url'].fillna(df['url_2'], inplace = True)
df['url'].fillna(df['url_3'], inplace = True)
df['url'].fillna(df['url_4'], inplace = True)
df['url'].fillna(df['url_5'], inplace = True)
df['url'].fillna(df['url_6'], inplace = True)

df.drop(['url_2', 'url_3', 'url_4', 'url_5', 'url_6'], axis = 1, inplace=True)

# %% [markdown]
# ## parse the wallet

# %%
df['wallet'] = df['url'].apply(lambda c: c.split("=")[1] if type(c) == str else np.nan)

# %% [markdown]
# ## display the dataframe

# %%
df
# Out:
#      #followe_by_team  retweet_count  favorite_count tweet_created_at  \
# 0                   6              3               7    0628/07:18:22
# 1                   4             37              68    0626/17:05:54
# 2                   2             52              54    0626/19:11:52
# 3                   2             17              21    0627/08:48:51
# 4                   1            157             152    0626/17:14:50
# ..                ...            ...             ...              ...
# 129                 0              1               1    0627/02:47:48
# 130                 0              1               1    0626/21:55:31
# 131                 0              1               1    0626/17:45:00
# 132                 0              1               1    0626/17:08:33
# 133                 0              1               1    0626/16:34:22
#
#      followers_count  friends_count  followers_count/friends_count+1  \
# 0               2376           3194                                0
# 1                376            308                                1
# 2               1986           1938                                1
# 3                390           1124                                0
# 4                625           2043                                0
# ..               ...            ...                              ...
# 129              143            236                                0
# 130              200            302                                0
# 131              288            761                                0
# 132              926           1747                                0
# 133              132            374                                0
#
#      statuses_count  favorites_count  \
# 0              9750              606
# 1              3559             7532
# 2              9290             1149
# 3               641              353
# 4              3417             8842
# ..              ...              ...
# 129              71               60
# 130             386              213
# 131            1147              338
# 132           16619            12947
# 133             453              277
#
#                                            id account_created_at  \
# 0    twitter.com/_/status/1277139262710771712          2016-0413
# 1    twitter.com/_/status/1276562341111517192          2017-0425
# 2    twitter.com/_/status/1276594041094729729          2012-0719
# 3    twitter.com/_/status/1276799644459139074          2019-1211
# 4    twitter.com/_/status/1276564588780085254          2013-0422
# ..                                        ...                ...
# 129  twitter.com/_/status/1276708782462996480          2019-0725
# 130  twitter.com/_/status/1276635228858011648          2018-1112
# 131  twitter.com/_/status/1276572183586762753          2013-0803
# 132  twitter.com/_/status/1276563011457519616          2014-0126
# 133  twitter.com/_/status/1276554407052603392          2018-1013
#
#          screen_name            name  \
# 0          Boriel_GR           BorGR
# 1       theartistmsg            Mach
# 2     fandiyusuf_710           F🅰ndy
# 3            10_jein           Naile
# 4     pandampramudya          Pandam
# ..               ...             ...
# 129     Aman06161548            Aman
# 130          Sanjoc2          SANJOC
# 131       Ridhopambd            Coin
# 132  gagah_nu_hollic  ꧁༻☬𝑁𝑢ℎ𝑜𝑙𝑙𝑖𝑐☬༺꧂
# 133         sufira12          sufira
#
#                                                    url  \
# 0    https://www.harmony.one/#boriel_gr=one15ndfckg...
# 1    http://harmony.one/#theartistmsg=one1wz3fxuuh2...
# 2    http://harmony.one/#fandiyusuf_710=one1gefg99y...
# 3    https://harmony.one/#10_jein=one19hkwxccudmtve...
# 4    https://harmony.one/#pandampramudya=one1mcex57...
# ..                                                 ...
# 129                                                NaN
# 130  http://harmony.one/#Sanjoc2=one149wd0ae4f4j0mk...
# 131                                                NaN
# 132  http://harmony.one/#gagah_nu_hollic=one1k2r54g...
# 133  https://www.harmony.one/#sufira12=one1qt07z98a...
#
#                                          wallet
# 0    one15ndfckgzhtz3cadxhhr52227s5yqw4xu28fcqg
# 1    one1wz3fxuuh2ecff9zc0sep96cnlrmpz6pwqnrp68
# 2    one1gefg99yyrmmurguzt8madmcxzr4puyr93lx3v9
# 3    one19hkwxccudmtve2svzj7mvds0ag43we9svtm6y5
# 4    one1mcex57vkq460qc3j56vuze4dzz0wua2hlq4s58
# ..                                          ...
# 129                                         NaN
# 130  one149wd0ae4f4j0mkkyqchgkzhfz0aacttt8fglv5
# 131                                         NaN
# 132  one1k2r54g25qtftg8rlnsypg9darvjdyf8jfq5hmm
# 133  one1qt07z98asgj9fs4l5js84w3qpn8vlcn3knvsm4
#
# [134 rows x 15 columns]

# %% [markdown]
# ## save the dataframe to csv file

# %%
df.to_csv("json/angels-20200702.csv")
print("save in the http://analytics.hmny.io/edit/harmony-log-analysis/projects/tool/json/angels-20200702.csv, you can download it")
# Out:
# save in the http://analytics.hmny.io/edit/harmony-log-analysis/projects/tool/json/angels-20200702.csv, you can download it
