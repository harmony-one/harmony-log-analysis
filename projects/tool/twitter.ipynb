# %%
import requests
import json

# %%
name_lst = ['stse','rongjianlan','leo_hao','denni_swon','gupadhyaya','AndrewIsTyping',\
            'cottontail2000', 'thechaindev', 'xiaopen01917726','janetlharmony','danielvdmaden',\
            'YishuangC', "potvik1", "haodi2best", "JackyTheCoder", "sahildewan",\
            "nickwh8te", "lijiang2087", "chaowen28", "dirschmidt", "nickostopoulos",\
            "GIZEMCAKIL", "maggiewangharm1", "niteesh_harmony", "vasilich_nick",\
            "mannymcoy", "SonnyNeverKnows", "CB_Cryptalk", "danboyden", "drop101001",\
            "alex_yatesalex", \
            "IScirlet", "iBruno_marshall", "sophoah", "JB273_Jurgen", "yelllowsin",\
            "mindpop3", "mirrormirage0"]

# %%
def get_twitter(name):
    url = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name={}&count=200&tweet_mode=extended".format(name)
    headers = {
        u'x-csrf-token': u'd39ff7dfbf373012ea78f82d9888d9ed',
        u'authorization': u'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
        u'cookie': u'auth_token=aaaa326d1ee4f9248644fc06996d9ea7ea4e950b; ct0=d39ff7dfbf373012ea78f82d9888d9ed',
    }
    res = requests.get(url, headers=headers)
    content = json.loads(res.content)
    return content

# %%
def print_twitter(twitter_id):
    for name in name_lst:
        print(f"==={name}===")
        content = get_twitter(name)
        for i in content:
            if i['in_reply_to_status_id'] == twitter_id:
                print(i['full_text'].replace("\\n", "..").replace("&amp;", "&"))
                print()
                break
        else:
            print()

# %%
twitter_id = 1274078228274012160
print_twitter(twitter_id)
# Out:
# ===stse===
#
# ===rongjianlan===
# @stse @HuobiGlobal @StakingRewards @synthetix_io @idexio @VitalikButerin @DirSchmidt #pow25
#
# 1. Slot increase announced and implementation tested on testnet.
# 2. Finished technical design for resharding and fast sync  with @gupadhyaya and @JackyTheCoder.
# 3. Huobi token swap technical solution.
# 4. Coinbase Rosetta research.
#
# ===leo_hao===
# @stse @HuobiGlobal @StakingRewards @synthetix_io @idexio @VitalikButerin @DirSchmidt #pow25
#
# 🥵 scalability fix of p2p message validation, reduce the excessive goroutine on validators
# https://t.co/6iBRVhBJcy
#
# 💡see light during the test on mainnet to collect 100% signatures.
# https://t.co/46rk4XOGm6
#
# ⛑️ new rolling upgrade script using @ansible is cool. https://t.co/MPxdcWTbHw
#
# ===denni_swon===
# @stse @HuobiGlobal @StakingRewards @synthetix_io @idexio @VitalikButerin @DirSchmidt #pow25
#
# 🚀 @harmonyprotocol dev grants proposals, pushing for #defi #crossfi #dapps on #mainnet
#
# ...
