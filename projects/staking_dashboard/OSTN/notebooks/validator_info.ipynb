# %%
import json
import pandas as pd
import numpy as np
import os
from os import path
import time
import requests
import csv
import re
from collections import defaultdict

# %%
def get_information(method, params):
    url = 'https://api.s0.os.hmny.io/'
    headers = {'Content-Type': 'application/json'}
    data = {"jsonrpc":"2.0", "method": method, "params": params, "id":1}
    r = requests.post(url, headers=headers, data = json.dumps(data))
    content = json.loads(r.content)
    return content

# %%
def getAllValidatorInformation():
    method = 'hmy_getAllValidatorInformation'
    params = [-1]
    return get_information(method, params)['result']

# %%
def getBlockNumber():
    method = "hmy_blockNumber"
    params = []
    num = get_information(method, params)['result']
    return int(num, 16)

# %%
def get_size(size):
    html_url = "https://staking-explorer2-268108.appspot.com/networks/harmony-open-staking/validators_with_page?active=true&page=0&search=&size={}&sortOrder=desc&sortProperty=expectedReturns".format(size)
    res = requests.get(html_url)
    content = json.loads(res.content)
    return content['total']

# %%
def get_validator(page, size):
    html_url = "https://staking-explorer2-268108.appspot.com/networks/harmony-open-staking/validators_with_page?active=false&page={}&search=&size={}&sortOrder=desc&sortProperty=expectedReturns".format(page, size)
    res = requests.get(html_url)
    content = json.loads(res.content)
    return content['validators']

# %%
def read_csv(csv_file) -> (dict, list):
    r = requests.get(csv_file)
    s = [x.decode(encoding) for x in r.content.splitlines()]
    d = defaultdict(list)
    v = []
    id_name = []
    for line in csv.reader(s):
        group = line[1].strip()
        id_num = re.sub(r'/\d+$', '', line[3].strip())
        address = line[7].strip()
        if group in groups and re.match('one1', address) != None:
            d[group].append(address)
            v.append(address)
            id_name.append(id_num)
    return d, v, id_name

# %%
def drop_duplicate(df):
    dp = df[(df['id_name'] != "") & (df.id_name.notnull())]
    dp = dp[dp.id_name.str.contains("www.ankr.com") == False]
    df = df.loc[list(set(df.index) - set(dp[dp.duplicated(subset = ['id_name'])].index))]
    return df

# %%
def diffAndFilter(map1, map2):
    map3 = dict()
    for k, v in map2.items():
        if k in map1:
            if v - map1[k] != 0:
                map3[k] = v - map1[k]
    return map3

# %%
def getNewValidatorInfo(address, df):
    index = df[df['address'] == address].index[0]
    return df.loc[index]['name'], df.loc[index]['security-contact'], df.loc[index]['website']

# %%
bls_key = []
availability = []
name = []
epos_status = []
apr = []
delegation = []
committee = []
website = []
details = []
address = []
security = []
identity = []
boot_status = []
dels = defaultdict(int)
# get the accumualted reward in current block
block = getBlockNumber()
next_block = block + 1
validator_infos = getAllValidatorInformation()
for info in validator_infos:  
    for d in info['validator']['delegations']:
        del_address = d['delegator-address']
        reward = d['reward']/1e18
        dels[del_address] += reward
        
# # get the new accumulated reward in next block
print("-- Need to wait for the next block to get the reward changes --")
while block < next_block:
    block = getBlockNumber()
    
validator_infos = getAllValidatorInformation()
new_dels = defaultdict(int)
for info in validator_infos:
    if not info['metrics']:
        bls_key.append(np.nan)
    else:
        bls_key.append(len(info['metrics']['by-bls-key']))
    if not info['current-epoch-performance']:
        availability.append(np.nan)
    else:
        availability.append(info['current-epoch-performance']['current-epoch-signing-percent'])
    name.append(info['validator']['name'])
    epos_status.append(info['epos-status'])
    apr.append(info['lifetime']['apr'])
    delegation.append(len(info['validator']['delegations'][0]))
    committee.append(info['currently-in-committee'])
    website.append(info['validator']['website'])
    details.append(info['validator']['details'])
    address.append(info['validator']['address'])
    security.append(info['validator']['security-contact'])
    identity.append(info['validator']['identity'])    
    boot_status.append(info['booted-status'])
    for d in info['validator']['delegations']:
        del_address = d['delegator-address']
        reward = d['reward']/1e18
        new_dels[del_address] += reward
# get the reward the validator earned in that block
reward_dict = diffAndFilter(dels, new_dels)
# Out:
# -- Need to wait for the next block to get the reward changes --

# %%
# get most infos except reward and uptime
df = pd.DataFrame(list(zip( name, address, website, details, security, identity, epos_status, committee, apr, delegation, bls_key, boot_status)), \
                  columns =['name','address', 'website','details','security-contact','identity','epos-status', 'currently-in-committee', 'apr', 'delegator-num', 'bls-key-num', 'boot_status'])
df.reset_index(inplace = True, drop = True)
# get reward per block
reward = pd.DataFrame(reward_dict.items(), columns=['address', 'reward'])
df = df.join(reward.set_index("address"), on = 'address')
# get accumulated reward
acc_reward = pd.DataFrame(new_dels.items(), columns=['address', 'acc_reward'])
df = df.join(acc_reward.set_index("address"), on = 'address')


# get uptime
size = get_size(1)
pages = size // 100 + 1
# get the validator info
validator = []
for i in range(pages):
    val = get_validator(i,100)
    validator.extend(val)
uptime = []
address = []
active_nodes = []
elected_nodes = []
active = []
for i in validator:
    uptime.append(i['uptime_percentage'])
    address.append(i['address'])
    active_nodes.append(i['active_nodes'])
    elected_nodes.append(i['elected_nodes'])
uptime_df = pd.DataFrame(list(zip(uptime, address, active_nodes, elected_nodes)), columns = ['uptime-percentage','address', 'active_nodes', 'elected_nodes'])
df = df.join(uptime_df.set_index("address"), on = 'address')
df.to_csv('./csv/validator_info.csv', index = False)

print("-- Epos Status Summary --")
count = df.groupby('epos-status')['epos-status'].count().reset_index(name = 'count')
elected, eligible, ineligible = count['count'][0], count['count'][1], count['count'][2]
print("Currently elected: %s \nEligible to be elected next epoch: %s \nNot eligible to be elected next epoch: %s \n" % (elected, eligible, ineligible))
# Out:
# -- Epos Status Summary --
# Currently elected: 193
# Eligible to be elected next epoch: 208
# Not eligible to be elected next epoch: 202

# %%
csv_link = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTUUOCAuSgP8TcA1xWY5AbxaMO7OSowYgdvaHpeMQudAZkHkJrf2sGE6TZ0hIbcy20qpZHmlC8HhCw1/pub?gid=0&single=true&output=csv'
encoding = 'utf-8'
groups = ['team', 'p-ops', 'foundational nodes', 'p-volunteer', 'hackers', 'community', 'partners']
by_group, csv_validators, id_name = read_csv(csv_link)

# %%
id_df = pd.DataFrame(list(zip(csv_validators, id_name)), columns = ['address','id_name'])
id_df.drop_duplicates(subset = ['address'], inplace = True)
new_df = df.join(id_df.set_index('address'), on = 'address')
lst = []
for name, group in new_df.groupby('epos-status'):
    lst.append(drop_duplicate(group))
new = pd.concat(lst)
print("-- Epos Status Summary (Unique) --")
new_count = new.groupby('epos-status')['epos-status'].count().reset_index(name = 'count')
elected, eligible, ineligible = new_count['count'][0], new_count['count'][1], new_count['count'][2]
print("Currently elected: %s \nEligible to be elected next epoch: %s \nNot eligible to be elected next epoch: %s \n" % (elected, eligible, ineligible))
# Out:
# -- Epos Status Summary (Unique) --
# Currently elected: 187
# Eligible to be elected next epoch: 205
# Not eligible to be elected next epoch: 185

# %%
dp = new_df[(new_df['id_name'] != "") & (new_df.id_name.notnull())]
dp = dp[dp.id_name.str.contains("www.ankr.com") == False]
dp_count = dp.groupby('id_name')['id_name'].count().reset_index(name = 'count')
lst = dp_count[dp_count['count'] > 1].id_name.tolist()
dp['is_duplicated'] = dp['id_name'].apply(lambda x: True if any(i in x for i in lst) else False)
dp_address = dp[(dp['is_duplicated'])][['address', 'name', 'id_name', 'epos-status']].sort_values(by = 'id_name').reset_index(drop = True)
print("-- Duplicate Validators --")
dp_address.to_csv('./csv/duplicate_validators.csv', index = False)
print("Save duplicate validators to ./csv/duplicate_validators.csv")
# Out:
# -- Duplicate Validators --
# Save duplicate validators to ./csv/duplicate_validators.csv

# %%
new_validators = [x for x in df['address'] if x not in csv_validators]
print("-- New Validators --")
print("New Validators: %d" % len(new_validators))
for i in new_validators:
    name, security, website = getNewValidatorInfo(i, df)
    print("Address: %s, Validator Name: %s, Security Contact: %s, Website: %s" %(i, name, security, website))
# Out:
# -- New Validators --
# New Validators: 246
# Address: one17y6w09aem8pj7t7cx28xa75jq3qzwlnv83xm5z, Validator Name: HARMONY 2500 SATS EOY, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1lsvf8fms0emzvw45eazx855cdjh6x467fa4ad8, Validator Name: NunuxNode, Security Contact: , Website:
# Address: one1rqpu3209r90dacjvh2tv9c53wdnweecrtlr2hk, Validator Name: LH2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1n0t2sxc02ss8jmvcxyrptruu69a62xj35a75jc, Validator Name: LH2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one15hvt2vq2hhh5parkgel5dcamhwcn2dlnu2kaec, Validator Name: Cabbage_autonode, Security Contact: Cabbage, Website: harmony.one
# Address: one1g520fddr2y4skj7crgp607uzzammlyy6tqgrln, Validator Name: greedy_autonode, Security Contact: sperm whale, Website: thepirate-bay.org
# Address: one1z2mk04tjw0ttascmvznu9pq7zpuz9e3l0qxssp, Validator Name: johnsmith node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ehyhce5h9f62xat2970gdtsa7sddmz5n6rajpp, Validator Name: Wang Lee - Validator 2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y5044jpnt2egetcpuaw4ng3d2egfp92j3cx5rj, Validator Name: Wang Lee Validator 1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1085xpmusueefvfx8lcx93xearltfp4m25y7saj, Validator Name: Agrest_one, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1f8hrk0l4a36hxsl8g6kqtg5ghqvzwg35s9y0sk, Validator Name: Harmony Validator, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1quutl0nazsg8h8m9vlpae2t6q6vphk20uvcd52, Validator Name: Lame_ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1l383hvyt34fdl3cvv9pggpu5wtwmm0ykn0ck6z, Validator Name: Pickle, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1xnzpe9aqgm7aqd9f4sgzm5ycqgmw7uga43f2gd, Validator Name: Tats, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14nxnrgag980uuw9qwknmpak77gaxh3sghdfmwm, Validator Name: Jagon, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y5sjr75g77f5ujatg5ldj47gmrxutr265jn5zl, Validator Name: LH, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1wjy6mtwxh6vfv9k7flcxxux9n3mrdjcg7p65qn, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rshxndhv5dv9phpeg8fkjy9tesh89pca20ltyu, Validator Name: EasternShire, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one12837rcusyck7djv8vc5e7uemmjntxpql832v9a, Validator Name: udinujang, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one12sf09xk4dary05tewp35xupfjj78q9urvpz6wf, Validator Name: Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one18pe7fuy90n3dr73hcc8gv6glxpvzvv77km6rlj, Validator Name: OSTN_ANKR, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1sxrm9t59gvdh7ghmpj8aqfazj2lr5ysspqk2zx, Validator Name: FANIN5050-000001, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1kcrs7j2g3hdpg23532exxnk44203zkdepryq5u, Validator Name: FANIN-0000003, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1z3jvhmlcy8v00gxecm2cm2j2zuedjlf6ceuut6, Validator Name: ESValidator, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19qdw8ge9wgt3e2759stjevuccz4qflw4rr3lwg, Validator Name: FANIN5050-000002, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19a09q6cwhk2nnty09elwmy6l2479mw9werhxa4, Validator Name: TitsWrinkler, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1zyapxr0gl5fxn7agu0laermpu7uteamslmqu06, Validator Name: WetFinger, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1p53a77uus9se68dlnh39en5zyj9d0z6nw4a2ge, Validator Name: SadCracker, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1e5wqxk8j6uemlar3vezkla89xyg22chzn2ttny, Validator Name: AssLicker, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1mhxpn2m2w22nuwr5gj7a3dv80p93kwnynrfepl, Validator Name: kris, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y8j6dpxpvyv8qsf059y6jphc8gkrj82905sgug, Validator Name: stakinglion, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1pwt0hfjcyc0wpu2c2qy3xpnwkrn95kf98m0r95, Validator Name: ATS, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1msf2aqddmsfpknr7026kpy48ev3wm9s8xnv55f, Validator Name: LEMONed_ONE, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1hdc4ags59esg62l3hk996hw0kd9ltru4zjwdfz, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1v90w0zk3sesxz4w2d6a3pgtr9gchc20t74gs0z, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1sn945vf20hm5ej7nlss2x3cmt69m6ugelwzems, Validator Name: Harmony-Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1gh8uq0hezn63tfgyj92djy5fefh097z0xjc8e0, Validator Name: VinayHarmonyAnkrUP, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1pdl9qsz55kmzjmprl4rg59h90l0z8fff9v9svn, Validator Name: Emiel-harmony-staking, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1wnatpk7rg43ymcz6vzgr6suwczd3e3mrvegez3, Validator Name: NodeKing, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1aurqsw253swcptz5ecsqpl2qlgqt0elp0x74mp, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1t97dewkfg2m9tq9n7lkarjame90nxexfz8ntlv, Validator Name: 0 Harmony-staking-main, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1tvxscsmhu7ere28anv49chpz4mqq6uq9utjask, Validator Name: my_hrmny_node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one13t0q3w935wpdr6avq3fe4uspw8eyy0xs2yu6gr, Validator Name: adrianoaleixo, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1qpeg7clhwgj9a2vaux369p4rryfnh70lxzqla2, Validator Name: s5, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1k0q8agszu8etphtfnx0934ltsyyrhvnwnjka2z, Validator Name: Kayy, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1hejlvrsfu8en3r6je2kyf6f95xnj8dqw9ed4xq, Validator Name: C10NU7 Ankr_Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1uq0dprttr2k3xn5ssd8dnkhj49yhvza3reynlr, Validator Name: Phuong Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one175uavfqvzqg0lp2eaankpr8u7jpm8rw5kvlpw6, Validator Name: Minh Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1dts6snty059wk48k9lyyraly6p9642gl2dg02j, Validator Name: Nham Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1c8mckkvg9rcltdjep4dp2crdxe70nx9v3egg7z, Validator Name: Thanh Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1mwpfkyr7l5d05hqy2h6mc56fez0y8dv74hr89j, Validator Name: Nga Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1e5lwy7a0jx45v5mjvujflrey4wtpvew4zlrq9j, Validator Name: Thao Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1yt0xugdy30ejkz9wfjwtfzm7gcflg90zs6pyzd, Validator Name: pathonenode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ndfd2ms5pz69w5rnnn4t5xxnyp4nfx74wpjxdz, Validator Name: 020 Node Ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1xpcyzyklwks720zynyct8xzrzrryhdlvxhev0w, Validator Name: AnyoneCanStake, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1u8j7yczgvc3c0c24qrz54pcjde424pcstcyaeu, Validator Name: GeekGuyAus-Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one18mlc36jnkj5njxx0pm8facvkrenmudu907x4t3, Validator Name: MR Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1m89dcfmatgc05g6x6sa63ch7r6n46z5qwstfjs, Validator Name: Blockgem Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one12lwj5h27ne8ada20s7ya5qzmwvuwpsj423kcg7, Validator Name: MR020 HRMNY Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19lrfewf9v37lxyfnsehkzqlvgluzyehhr3ds2p, Validator Name: Satoshi Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1du3ay9c6zplj24j3xhwvscrruhxs9vamzsxy9n, Validator Name: Honey node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1nvwp873xy7ypcqd5jkaq0gvjchtcqdmhrl4fjf, Validator Name: harmony test autonode, Security Contact: alla, Website: harmony.one
# Address: one1c43tg8ug4tl7wzyvax9urgnv7g4ndk9zxdyz8e, Validator Name: Maria Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1unc4nv7dwjywdlnwezqy4944cxpcyjeruum8ee, Validator Name: Just a nerd, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1sa0g9g22qjk4yxk95ymyrcg2aysh2yv97mtqqm, Validator Name: Harmonaut, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one13nfsuxwfqp4hvektmu6u0wrd77kzwtv5r35ftx, Validator Name: JUANKURD, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cw20yk26ldnl4qy7j8mf5eelt5ugdvxgxmwyv4, Validator Name: NikolaosKost, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1agn3lmpzklp0yashn0t49fhqqpc3u9nwu48kwv, Validator Name: GigglyWiggly, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1l8fjq8ygqesk20qkek6ldfrfhjzw64luxlk7l0, Validator Name: Manny, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1vll689y3dwz9h3d9g4rh5z68yfpvqzxgwyxgm9, Validator Name: 2500 Sats, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19wyux0m57azlzxtsvhs3dtnhr3eg8eepmy98yn, Validator Name: kuitk, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1du5yacdfaeezww9mzxje7vgdy9j0lhyl5lgt68, Validator Name: KB-H1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1sflhvu404tvkryce5kxx2e9qzgfdsjgaf3203u, Validator Name: Soraia, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one130tk66tfjnecsunj7zt5gl6rdj06fyr66r25uj, Validator Name: Tokyo, Security Contact: anttut@gmail.com, Website: siptune.com
# Address: one1rw7fwv4zw8hzdmrccskxqrgygnqfsqx2qycfcd, Validator Name: Lucky, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one16yla6w8ue0vg3zyl5luvza23qqwg52yq08zs4g, Validator Name: VinayHarmonyAnkrUP, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1xgwkf8n3fn7emlxkszymn7k7tp4qk9ptp93mx5, Validator Name: Harmony-1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one136f6ry9akqj8kj3zlgx38zy8f433h346dnxgxy, Validator Name: Shakash, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one10m4yp8s7gunz5cpz6shrved8kfemfhyt5c377v, Validator Name: pathNode, Security Contact: path, Website: pathrock
# Address: one1nzkhudzmyczmy0ukvjewlx4zyqjmc8ujhfhq90, Validator Name: Dark Angel One, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1qpwkx8d63p44t7vgh7stl3s8phr6szej3pjnmh, Validator Name: Ankr Staking, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1lz6h2slntpvk0d7wuzswgzewwmwyj0x64q7nfy, Validator Name: Ankr Stak, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cv5akjw5yk5ryhkhehey05w38jypas5550xahm, Validator Name: Maggie key8  autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1ff43kztajacdw4093w73vdtxxjcz37m0xfc3sm, Validator Name: Donh48, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1356zj4kwxxyl5wvez4w54608uq84zucueyq927, Validator Name: FANIN5050-000001, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1gdvwd9vampmpta4q8qt2aj8nq32hmj06setxm0, Validator Name: adrianoaleixo, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14shk8s5ucmueku9hjyccvwxkgu6tky9rrzdfc8, Validator Name: One Test Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14vrwvgn7yeamgp75jgj73ucl2xnxvlnsm2aa8v, Validator Name: Myfirstnode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one10qaqxgfwgdkjcmcehqq9ufl4pqaup3rdmg8elg, Validator Name: Crypto Wolf Ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y0l3crfuhmf48yh8ynhd7ndmr7lhj5t0360cxp, Validator Name: Harmony-Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1lr978ndz96y9m9yfq6jw6uxhfwlreqvcrk4myn, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one10pk5pmg3tnxhwm5gpv95nqmzju4p44rqjlnk9a, Validator Name: NodeKing, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1zxhmchnykrudcyqan0f6tru3tsh5mej6jg6y4f, Validator Name: Chip, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19pd5yjhah2rt8hj4wdplyctzd2c50shhwhxv3q, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1w0f9fx3l2u34qq4u68k7gg307g0fqaq5f4rl8s, Validator Name: SIMNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1j3mjr9mfd4k2lhp5nuhc9c9m0mw57qg80gfnqz, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1mzt202nuppau8xx7g378p2p5ek8egar7m0mzvx, Validator Name: li-auto-non-docker, Security Contact: li@harmony.one, Website: li@harmony.one
# Address: one1tcdagh2wwlcnw5c2dwenz9k0t9ckssyrwy6c37, Validator Name: Coletier, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1z54v88a2u47zma7dmlsy2utcdr96wn05e2p9a9, Validator Name: Satoshi Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one16ky8rtgwqv2s8zjrr4mu5tc7fqa3htzp69xgyy, Validator Name: teesh_autonode no docker, Security Contact: Teesh, Website: harmony.one
# Address: one1kl3cpjkqqfqkmuduc3rztugfl77hjnmfj9023d, Validator Name: mindstyle autonode lambo moon party, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1uhnaur0ftwu7ytwhtgd7w4zx96tur7rd3rae4c, Validator Name: harmony_autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one12xzap0r4rrmfc7jcluuue70flw06v4wrw6chlu, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one14wqtuj0g548uw8gdqqfefqcx3vkct362y952kg, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1uz957sjlp6j2fgg5nxutm7d0sy0xqq0ysh80pu, Validator Name: MEASA DeFi UK, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1yt6les3uaftdeqp0x2897h2hfynz6mkhvn9ay9, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rkudkvml7vglxumkm24cz6s4zut5hqdwkkn40n, Validator Name: Medium, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1t46czjhc6ezjp6ce872ld7krdt70sz3gv5cxc5, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1qlm4at9u5d5wyqj8nzq9pu2wgmm6kq6vurjxzc, Validator Name: lepto33, Security Contact: None, Website: https://harmony.one
# Address: one17z0sx5wrzxdefa6t6mvxcv69frtmf6tjamalg2, Validator Name: gw@harmony.one, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1jywsynzhsped8q695hkcf8psyzwqhsax0dea8z, Validator Name: Satoshi node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1w0wq5jvdgnwappudspkf7xwkwzatykudhlyw2l, Validator Name: sava235, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1km2a6jnmq5j8ugxe4juwaf65qwk40ta8atde8s, Validator Name: Lester Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1jg5rezn9tqdgpg0awewu9khrg2y9alu3jjpc4e, Validator Name: td17, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one16j66pghpwks9c5ql2k52zamfva9hwh02nqfje5, Validator Name: TCMark007, Security Contact: TC, Website: TCMARK007.COM
# Address: one1tku5x2p9dap2t46cpp69whp2hprg8e5a63kx2c, Validator Name: BJxDJ, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1rr5jwz2njdss2yu8mh9ffag08x7m0cquhvz3e8, Validator Name: garlam_autonode, Security Contact: garlam, Website: harmony.one
# Address: one1kdjs72qn8efcnxycjj2wxnm0x5j9fyl0srfcdu, Validator Name: PUMP THIS SHITCOIN, Security Contact: Daniel-VDM, Website: pornhub.com
# Address: one1vzungjk0e0eddfpajpzlrtnu5cy4skh3hrcvtc, Validator Name: Izeet007, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14dwp6vzg3zc6xs6qxlmxe8rr5zp7alnj678vwe, Validator Name: Minh Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1sa6w2ceqgtz06k8d2ay4mzrtvu272wk8mwjufz, Validator Name: Deevansh Bhargava, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1v7ya7zzjzut6w4kpyqcp4nwllvahfrtzm9hfqn, Validator Name: Harmony Staking EC, Security Contact: CONTACT, Website: YOUR-WEBSITE.COM
# Address: one1wc4lu760jdsu3222yvtqhvdvsgq8qn5swsjwvs, Validator Name: MEASA DeFi - Mauritius, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1dgtd73aumt2vx2el35g8wqkjsj4yzxkjg7sx9d, Validator Name: AnkrHarmony_Darby, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1exltmz4c4pcsvc6n94zfyj08upv8mzsr8sdlj0, Validator Name: kengee no validator, Security Contact: CONTACT, Website: ipfs://f1.crypto
# Address: one1qhc0ageuh5lel82vwtzq6fvwsy7xvyu3nj7rvx, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rl88uu9x9u29x7d746546mre3jdr2zvrpx6n22, Validator Name: Pras_Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19tums5zggs2m0qts8gjvskdynqxkly39ec8wk7, Validator Name: KlanNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one12kkt8w3q4803vrm00nxs8jgud4flavvqsjeplf, Validator Name: DianaNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one17jxvaj34yth6rrlp08wryvxj342wvmrjypwaug, Validator Name: AndradaNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1nhf06vg0rxu5zal6nunh6as4l8l3nhna6tpp0v, Validator Name: One Enterprise, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1myz6h2hhl83lzd3f6uj0umlq2d9pr9u7ggtzk6, Validator Name: AnyOneCanStake, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1hqdwurrd52t4kh23d445gp8kx5s64cm8sc32ym, Validator Name: Babylon, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ru57l8e7629vp93fpakq429y9zg32t8evcau8u, Validator Name: ZGMF-X20A, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y67cq0m2d6t97kl2kk6pw8zpqmln7emh46ruh7, Validator Name: Bijinder, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1s9879eh9rswuxgxdjszzcxs3ratmr38ejpx9z2, Validator Name: Signore-One, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1k2zgm3xjjcfhepjku6z0h5aa5kp9y2r0m2wpvq, Validator Name: Timberlake, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cm0nd3nnjsld79arxf8q8g2f3lyps0fysccj32, Validator Name: maison889, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1upjqy8au5rfa70xwq52gvqsdjdcem5t44f8gtq, Validator Name: harmony node 1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1hlu0en4qmmpz6avcssjs8y3alu3g0rrj0cgqfy, Validator Name: first_validator_node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1pql90ygkjjx5usxs20c3v2j9lq56f4rt9q0qj0, Validator Name: harmony node 1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one134zsgwfh78jn3968970k50ggn90l7zxnjar3ah, Validator Name: Harmony Validator, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one10xqrp8k7vy7mldyd88qg9vfuqlcqtlcl2wvlwx, Validator Name: Soph Sybil validator 1 attack test, Security Contact: Soph-sybil, Website: soph-sybil.harmony.one
# Address: one1cnqc5wnn5j09jecqu5fl46daz6uleygafm79ft, Validator Name: fayeloon, Security Contact: CONTACT, Website: YOUR-WEBSITE.COM
# Address: one1gs5qc2uhy0v4m3tqukeefjnppgl23cmktgkz78, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one17k45klp4p67ej0kmt38jjka0ne4aweu02rp8ke, Validator Name: harmony-1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1suq0c5m8gldxu907n3guu0vxwvkaf252dsf7ct, Validator Name: ZapadaWhiteNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ef46ztuzd2024c8dawrvs6m92v06juswzls5d6, Validator Name: OmatHohNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one15ew26clcdskchuwlh9c8casm2mfwnhqerldfj3, Validator Name: kostetx_mode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1m566edjs8ska8pmmhp0yeerl0t63kzsk338svm, Validator Name: li_420_auto, Security Contact: li2harmony.one, Website: li@harmony.one
# Address: one1fn554v95gw2htufxpyrk6r2wejr46gx0ewwpqn, Validator Name: Brenna, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1jjx8exhj04xrxrl0vp8dzjxwf220qfxhmr7ku4, Validator Name: toney02, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one17ajlf77k48xsfd22dvefag4yd7wp4wsrv52zq5, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1cvu989jl0wz00zyefmtfgnhw7syxa9ufptxjez, Validator Name: AndersonSanjiOne, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1m8nperpw6hpczg7ql9ya2qqjhvesaejkqy906h, Validator Name: Mai Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one10acs8g3ehxrs8lw5lr5msdjystkckgrs9nu69d, Validator Name: Alex1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19xageely0jzs997stfdt6gjv7ay9ka9qhejugw, Validator Name: Xiaomi, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1lpzdnqz47xnpand6k33zw6zlwx3fxc0veftt3r, Validator Name: mercyolekwuamos22@gmail.com, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1xvszdusx787aljdu67thdzwxmrjvq6qwjyss48, Validator Name: lorriz, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1tk9v80w5seja0zy42nfknyxk9acea9xketw9j0, Validator Name: err0r ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1u0n3mnzdysgk9lcz4j0zmfe48ceqc8ja6ewekc, Validator Name: LEMONed-ONE, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14438psd5vrjes7qm97jrj3t0s5l4qff5j5cn4h, Validator Name: edgar autonode, Security Contact: someone else, Website: hyegar.com
# Address: one17t9lnckx3dcqzvryfv42ezsrhuast88r4m745r, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1ge0rdtkpdu2zqtrr6n04t56dnx2gn0atj6lah5, Validator Name: SVET, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one17u02mjqlkg054damrta0tgxykp6prens9zzmr5, Validator Name: Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1djkq87la8gne37z5esh09f9g4d2snwrwq2eqhg, Validator Name: sss ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1lkr2fd3tlzsx2lf45k424njlqcvjy9576ufrv6, Validator Name: hieuda8, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19h29g5tnatu5yyy5fd66a498ztcp0h33nwvrvl, Validator Name: ushakov, Security Contact: ushakov, Website: none.none
# Address: one1jv33x42xlz0uquyar7dpqjkl59vqxxy0a8zrgg, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1576mdu3wxlh2rysnssys4842gjz3maye34tls2, Validator Name: tanghaobing, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1u889mw6c6z3n76hw7flx92py5kaq5drmem9u5h, Validator Name: chlhs, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1068dt8rl6e04zkvjakadptjecehxfy0run7d3x, Validator Name: 12312313, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19d87pqvma92juyyq92njnrsda7y7dxh5nlm3kz, Validator Name: gondar, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1nfueclajkh4jxx045sdnym6tdz3jjm3y9c9xpj, Validator Name: prince node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one15s8kzj5m4gdxentv29l44xu8mt8g3gvuzc9yww, Validator Name: SanTri1983@Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1d587g2cmsh78x7anqhckzxwll3yqlv5c2ahhp3, Validator Name: Zahid Malik, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1shn56j2ja5axqjmld5jq6jalpsgs0s4mny60g4, Validator Name: stanley_harmony_test, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cdrxy5v5nkgavgz0anznsxj878gwm2ja53y4lc, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one18l9mlds7awmjl2gnnfhufghzccadmts5mq85cj, Validator Name: davidbarker, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one15v6n68x3sz2wc73quza0fpt8ckm5marr0pn0u5, Validator Name: davidbarker2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1f9hjaxkwufhge829wp590klgkrp5c04fe8q34g, Validator Name: davidbarker3, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1zv657mgcaxgrqxmxn2tz3xvkvxt00uzmzr9nst, Validator Name: OneAnkr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one19ryw24xzf9hu7ck96mn6e8zdf6vvtlh050hjac, Validator Name: Vega autonode, Security Contact: NA, Website: harmony.one
# Address: one1kpuag42sjyd995g4z37u8f02g3pj49zc6g42qm, Validator Name: 25554118, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one178snqxsfg28v0xa6n2y2768s6tek3d45fgeqh5, Validator Name: kengee no delegate, Security Contact: , Website:
# Address: one1jy0a490u77phe6h9ms9gaeaupvcq9gpzq9cy9u, Validator Name: cryptoperks, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1r2l2jql3wf0ggck42ctm3q2e83ytehl0dvmp6r, Validator Name: @harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1d5fqtsmls8dmp9e4dp9q4eykm2feeeswj7xch9, Validator Name: test ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cqm3r8yqzp6rrglsv3dt932h702yx6jsj7cks9, Validator Name: test ankr, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1fchs24cqnzyxsxzmulxsldru7zl3zahxwwyqnk, Validator Name: GeekGuyAus-TestNode, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1y2ujv2dkvskq6c2qemc8qnccuz2h62yydvvdjr, Validator Name: Nga Harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ar5smjmnsjf4ke6skh4a4wyuune5muckexf3a7, Validator Name: stanley_harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ehu2hngruj9crt8glxwvc5sk6cw08hqyrkyjdq, Validator Name: stanley_harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1xmd3pgd843c8m66fqq2aye0ts0zxp5y3ka4eae, Validator Name: stanley_harmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1ck0z2umfwy73wdsjy3cleznamakxejmx5asfaf, Validator Name: cat123, Security Contact: CONTACT, Website: YOUR-WEBSITE.COM
# Address: one1t4cjscu67gz0nnse2r82e37gh97nn44sx3lx09, Validator Name: Lefty, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one13qnewlw4znat8gmyga495qanlquf3v5ngpsg89, Validator Name: viera24465@gmail.com, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1z28zsvjvevexnnyyy2t5qv57vsx0ct7fvnnhl5, Validator Name: udinujang, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one102xvs5la4wfe9qut4nz76mxm7c3xx3jn4u95xx, Validator Name: looteraharmony, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one174q98vcynnzvqnvxx9nresc8mj36f2hj0guk5f, Validator Name: one-validator, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1fx37yl0sf774jxxpdndm3g20sm8tmrjx575m5l, Validator Name: ArmyIDs Node, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1tdce09gmnj3q96syqyu545aq0nrs696zwmclxa, Validator Name: MEASA DeFi, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1fcp7h93ylawd5q5ugwc26kw9vulxcdjqhlzdyd, Validator Name: MEASA DeFi 2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1cgq93ek3mx398j4ldy69s9epnglmj4k88335p3, Validator Name: Ankr-yuhui@ankr.com111-2, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1kl7urg9cm2xmn3ecsnlafjs2jacunmkhvvyqgd, Validator Name: Ankr-yuhui@ankr.com111-3, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1gpz989mxf6uzu4ctz4xra7xcrytk5pe2h2lnn9, Validator Name: sajklan, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1rd3qq0u789wj8a803wchx96rhgthhfhtdyuakr, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1gr0sku376snf9jqsmrp5qqn2wpatz7l6ml5duy, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one18dsfh3m995ncrc0txxxt34sr9vs52merfy9tlg, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rrv2lu0q2juu4jp3e282kcxx970qx8fj4wrl2u, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one10lduqcyu0yyfne02tjfkr8mrnsu8r6vjy05tw2, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1fra658z8r2c783meyytrv8anax4saqdkfyvwcc, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1znh6v3l4cjk8uzcmqukznmylpmnv3pjt3wed3d, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1a5kz495us9uqce5crx96kpecrcthy53jelhfvq, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1yn3ctgx08udeegtwpya2cqt4dlempg0rctlrlr, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rxnkpq087frx66yl6d5884rqdwpa250ja63qts, Validator Name: Thunderbolt, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one18dxy6eh2wsd2yqyr2tt6qrptrxl9pl44rt95fu, Validator Name: WeAreOne, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one10cuh4y3qjts7mz7nqf67rcms78gfv3jdpuqff5, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1el3arlc0dczjpr8crhufgszurt6hcmlm66evwa, Validator Name: ROZETKA, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1080c4h7uev7u68s330vnxsfw7h6t86ufer8923, Validator Name: artkrpt, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one16xt3gl6l7q8afksksgwdmdahd5s75trgy6ut3k, Validator Name: blink  harmony autonode, Security Contact: blink, Website: harmony.one
# Address: one13akr6683l3lfnfu44r3n9qnmq6la0fsy8r5kdv, Validator Name: SINTO, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1jhl3w8z3lvmyngym7apveus58vk2mmjn08jrdq, Validator Name: kengee no validator, Security Contact: , Website:
# Address: one1jkmsy3q0pelr9n5pjkaq7v5kqqa95k74d397t5, Validator Name: Dragon, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1z0jyvu5r33tudevf2n2j90tkp04hw8hdadna7w, Validator Name: cabbage, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1kenmx089nrzpkw0mlrux3zgd3rtvweas87zktu, Validator Name: NIK, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one187k8fc67m6eyh24elwhjj4mefeghws8tsx3h73, Validator Name: onion, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1h3ugwlrl825dchuaw7nrdtjqazl5yr7r3nv93s, Validator Name: pickle, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one17807m5hxz85xp7zdzm7d6ymef9s53s5jsxxcpf, Validator Name: wife_artkrpt, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1rlv3aas89p0qvzecpmatd3ja7tufa23038aljg, Validator Name: Mazda, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1z3jlenpduyghumdwp9eth58nsznvsht0sa76km, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1cy54nt7chpmgpya0sjn6g6avtuhypuz88dn3ys, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1sj6gn5024vjva68qlgzad2uleee4psrd3lmlau, Validator Name: harmony autonode, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1hvrcmtxfmewuk5yy5wf3tsy7p9zku5ep5lmucg, Validator Name: Marketing-harmony-staking-1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1yzp3yw8x848jazrz7w5a24zulum2nsjqnd9n67, Validator Name: s1, Security Contact: s1, Website: s1.one
# Address: one1y9353es2gghwyayz5xrgttz9zcs9tvz9sl4ew2, Validator Name: MasterYoda-UA, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1n6lp8jhfz9jsydkvpfd2fehsx7f70vkfq49jy7, Validator Name: Ankr-Prod-1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1kx365n6hwg9fv6uzjer3gljpqzx0egw4t6leum, Validator Name: sifawlt, Security Contact: @sifaw23, Website: airdrop.uno
# Address: one1c9wlqc54f85fx9ms9qrpfs7u3vhcqhl79zqgd8, Validator Name: NETMAN, Security Contact: NETMAN, Website: NONE
# Address: one1cdtqsylmmml9qf4r27dfljg4ws9ucf2jujz7gn, Validator Name: ToTheMooN, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1txs36hlawxjrjmzq97kdlacnt37acdwlgdfzaj, Validator Name: 777, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1m7jywak0wpj98082kps92smkgqm2839suscmme, Validator Name: 777-2, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1ygchq3eve4u2majguwh8e55k3ys8l4t5nex224, Validator Name: 777-3, Security Contact: Daniel-VDM, Website: harmony.one
# Address: one1g63evc5azju5jxhytfmn4z3p4qutmarm8n9j02, Validator Name: ocholi achemu-harmony-staking-1, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one1eafq3mchhamvtv34f9s3mz7y8nej5amqwk3lqd, Validator Name: Namtup, Security Contact: info@ankr.com, Website: www.ankr.com
# Address: one14yk0psfzn8tv2wrgw93huyllrq8te9s44d97zd, Validator Name: harmony Stylebender, Security Contact: Daniel-VDM, Website: harmony.one
