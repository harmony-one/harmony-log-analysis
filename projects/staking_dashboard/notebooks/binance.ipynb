# %%
import requests
import json
import pandas as pd
from datetime import datetime

# %%
url = "https://api.binance.com/api/v1/klines?symbol=ONEUSDT&interval=1d"
r = requests.get(url)
content = json.loads(r.content)

# %%
df = pd.DataFrame(content, columns = ['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close time', 'Quate asset volume', 'Number of trades', 'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore'])

# %%
df['Open time'] = df['Open time'].apply(lambda c: datetime.fromtimestamp(c/1000).strftime('%Y_%m_%d %H:%M:%S'))
df['Close time'] = df['Close time'].apply(lambda c: datetime.fromtimestamp(c/1000).strftime('%Y_%m_%d %H:%M:%S'))

# %%
df
# Out:
#                Open time        Open        High         Low       Close  \
# 0    2019_06_01 00:00:00  0.01500000  0.02848000  0.01091000  0.02402000
# 1    2019_06_02 00:00:00  0.02403000  0.02410000  0.01933000  0.02104000
# 2    2019_06_03 00:00:00  0.02104000  0.02372000  0.01959000  0.02127000
# 3    2019_06_04 00:00:00  0.02120000  0.02585000  0.02000000  0.02350000
# 4    2019_06_05 00:00:00  0.02346000  0.03036000  0.02228000  0.02835000
# ..                   ...         ...         ...         ...         ...
# 349  2020_05_15 00:00:00  0.00328000  0.00354000  0.00306000  0.00330000
# 350  2020_05_16 00:00:00  0.00330000  0.00364000  0.00318000  0.00332000
# 351  2020_05_17 00:00:00  0.00333000  0.00344000  0.00318000  0.00321000
# 352  2020_05_18 00:00:00  0.00323000  0.00356000  0.00303000  0.00347000
# 353  2020_05_19 00:00:00  0.00347000  0.00354000  0.00336000  0.00338000
#
#                   Volume           Close time  Quate asset volume  \
# ...

# %%
df.to_csv('../csv/binance.csv')

# %%
url = "https://api.binance.com/api/v3/ticker/24hr?symbol=ONEUSDT"
r = requests.get(url)
content = json.loads(r.content)

# %%
content
# Out:
# {'symbol': 'ONEUSDT',
#  'priceChange': '-0.00001000',
#  'priceChangePercent': '-0.293',
#  'weightedAvgPrice': '0.00344685',
#  'prevClosePrice': '0.00341000',
#  'lastPrice': '0.00340000',
#  'lastQty': '22500.00000000',
#  'bidPrice': '0.00339000',
#  'bidQty': '9774.60000000',
#  'askPrice': '0.00340000',
#  'askQty': '471828.90000000',
#  'openPrice': '0.00341000',
#  'highPrice': '0.00354000',
#  'lowPrice': '0.00332000',
#  'volume': '193628268.80000000',
#  'quoteVolume': '667407.09989100',
#  'openTime': 1589825033178,
#  'closeTime': 1589911433178,
#  'firstId': 3022276,
#  'lastId': 3027107,
#  'count': 4832}
