# %%
import json
import pandas as pd
import os
import gzip
import re

# %%
def read_data(files, path, date):
    data = []
    for file in files:
        if date in file:
            with gzip.open(path + file) as f:
                for line in f.readlines():
                    if 'Received prepared message'.encode('utf-8') in line \
                    or 'Receive announce message'.encode('utf-8') in line\
                    or 'Receive committed message'.encode('utf-8') in line:
                        data.append(json.loads(line))
    return data

# %%
def data_processing(data):
    df = pd.DataFrame(data)
    df['time'] = pd.to_datetime(df['time'], format = '%Y-%m-%dT%H:%M:%S.%f')
    df.sort_values(by=['time','message'], inplace = True)
    df.reset_index(inplace = True, drop = True)
    return df

# %%
def get_missing_msg_index(df):
    for name, group in df.groupby(df.index //3):
        if group.iloc[0]['message'] != '[OnAnnounce] Receive announce message':
            index = group.iloc[0].name
            print(index)
            break

# %%
log_dir = "/home/ubuntu/jupyter/logs/mainnet/34.212.183.107/"
files = os.listdir(log_dir)
data = read_data(files, log_dir, '04-19')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      9378
# [OnCommitted] Receive committed message    9379
# [OnPrepared] Received prepared message     9378
# Name: message, dtype: int64

# %%
get_missing_msg_index(df)
# Out:
# 3138

# %%
df.iloc[3132:3142]
# Out:
#       level  port              ip  \
# 3132  debug  9000  34.212.183.107
# 3133   info  9000  34.212.183.107
# 3134  debug  9000  34.212.183.107
# 3135  debug  9000  34.212.183.107
# 3136  debug  9000  34.212.183.107
# 3137   info  9000  34.212.183.107
# 3138  debug  9000  34.212.183.107
# 3139  debug  9000  34.212.183.107
# 3140   info  9000  34.212.183.107
# 3141  debug  9000  34.212.183.107
#
#                                                  caller  \
# 3132  /mnt/jenkins/workspace/harmony-release/harmony...
# 3133  /mnt/jenkins/workspace/harmony-release/harmony...
# 3134  /mnt/jenkins/workspace/harmony-release/harmony...
# 3135  /mnt/jenkins/workspace/harmony-release/harmony...
# 3136  /mnt/jenkins/workspace/harmony-release/harmony...
# 3137  /mnt/jenkins/workspace/harmony-release/harmony...
# 3138  /mnt/jenkins/workspace/harmony-release/harmony...
# 3139  /mnt/jenkins/workspace/harmony-release/harmony...
# 3140  /mnt/jenkins/workspace/harmony-release/harmony...
# 3141  /mnt/jenkins/workspace/harmony-release/harmony...
#
#                                     time  \
# 3132 2020-04-19 01:47:56.681301789+00:00
# 3133 2020-04-19 01:47:58.449389185+00:00
# 3134 2020-04-19 01:48:01.419759313+00:00
# 3135 2020-04-19 01:48:09.668910694+00:00
# 3136 2020-04-19 01:48:11.421768371+00:00
# 3137 2020-04-19 01:48:11.563534346+00:00
# 3138 2020-04-19 01:48:16.654107326+00:00
# 3139 2020-04-19 01:48:18.000227752+00:00
# 3140 2020-04-19 01:48:19.846507883+00:00
# 3141 2020-04-19 01:48:22.891395333+00:00
#
#                                       message  MsgBlockNum  MsgViewID
# 3132    [OnAnnounce] Receive announce message          NaN        NaN
# 3133   [OnPrepared] Received prepared message    3087118.0  3087198.0
# 3134  [OnCommitted] Receive committed message          NaN        NaN
# 3135    [OnAnnounce] Receive announce message          NaN        NaN
# 3136  [OnCommitted] Receive committed message          NaN        NaN
# 3137   [OnPrepared] Received prepared message    3087119.0  3087199.0
# 3138  [OnCommitted] Receive committed message          NaN        NaN
# 3139    [OnAnnounce] Receive announce message          NaN        NaN
# 3140   [OnPrepared] Received prepared message    3087120.0  3087200.0
# 3141  [OnCommitted] Receive committed message          NaN        NaN

# %%
data = read_data(files, log_dir, '04-18')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      11743
# [OnCommitted] Receive committed message    11743
# [OnPrepared] Received prepared message     11743
# Name: message, dtype: int64

# %%
data = read_data(files, log_dir, '04-17')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      9396
# [OnCommitted] Receive committed message    9396
# [OnPrepared] Received prepared message     9396
# Name: message, dtype: int64

# %%
data = read_data(files, log_dir, '04-16')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      11760
# [OnCommitted] Receive committed message    11760
# [OnPrepared] Received prepared message     11760
# Name: message, dtype: int64

# %%
data = read_data(files, log_dir, '04-15')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      9389
# [OnCommitted] Receive committed message    9390
# [OnPrepared] Received prepared message     9390
# Name: message, dtype: int64

# %%
df
# Out:
#        level  port              ip  \
# 0       info  9000  34.212.183.107
# 1      debug  9000  34.212.183.107
# 2      debug  9000  34.212.183.107
# 3       info  9000  34.212.183.107
# 4      debug  9000  34.212.183.107
# ...      ...   ...             ...
# 28164   info  9000  34.212.183.107
# 28165  debug  9000  34.212.183.107
# 28166  debug  9000  34.212.183.107
# 28167   info  9000  34.212.183.107
# 28168  debug  9000  34.212.183.107
#
#                                                   caller  \
# 0      /mnt/jenkins/workspace/harmony-release/harmony...
# 1      /mnt/jenkins/workspace/harmony-release/harmony...
# 2      /mnt/jenkins/workspace/harmony-release/harmony...
# 3      /mnt/jenkins/workspace/harmony-release/harmony...
# 4      /mnt/jenkins/workspace/harmony-release/harmony...
# ...                                                  ...
# 28164  /mnt/jenkins/workspace/harmony-release/harmony...
# 28165  /mnt/jenkins/workspace/harmony-release/harmony...
# 28166  /mnt/jenkins/workspace/harmony-release/harmony...
# 28167  /mnt/jenkins/workspace/harmony-release/harmony...
# 28168  /mnt/jenkins/workspace/harmony-release/harmony...
#
#                                      time  \
# 0     2020-04-14 22:50:15.561375756+00:00
# 1     2020-04-14 22:50:18.525176419+00:00
# 2     2020-04-14 22:50:22.042109375+00:00
# 3     2020-04-14 22:50:23.723591012+00:00
# 4     2020-04-14 22:50:26.740047604+00:00
# ...                                   ...
# 28164 2020-04-15 20:16:52.702605495+00:00
# 28165 2020-04-15 20:16:55.647165362+00:00
# 28166 2020-04-15 20:16:59.364493855+00:00
# 28167 2020-04-15 20:17:00.958669588+00:00
# 28168 2020-04-15 20:17:03.976010979+00:00
#
#                                        message  MsgBlockNum  MsgViewID
# 0       [OnPrepared] Received prepared message    3043785.0  3043865.0
# 1      [OnCommitted] Receive committed message          NaN        NaN
# 2        [OnAnnounce] Receive announce message          NaN        NaN
# 3       [OnPrepared] Received prepared message    3043786.0  3043866.0
# 4      [OnCommitted] Receive committed message          NaN        NaN
# ...                                        ...          ...        ...
# 28164   [OnPrepared] Received prepared message    3053173.0  3053253.0
# 28165  [OnCommitted] Receive committed message          NaN        NaN
# 28166    [OnAnnounce] Receive announce message          NaN        NaN
# 28167   [OnPrepared] Received prepared message    3053174.0  3053254.0
# 28168  [OnCommitted] Receive committed message          NaN        NaN
#
# [28169 rows x 8 columns]

# %%
data = read_data(files, log_dir, '04-14')
df = data_processing(data)
df.groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      11752
# [OnCommitted] Receive committed message    11753
# [OnPrepared] Received prepared message     11751
# Name: message, dtype: int64

# %%
df
# Out:
#        level  port              ip  \
# 0      debug  9000  34.212.183.107
# 1      debug  9000  34.212.183.107
# 2       info  9000  34.212.183.107
# 3      debug  9000  34.212.183.107
# 4      debug  9000  34.212.183.107
# ...      ...   ...             ...
# 35251  debug  9000  34.212.183.107
# 35252  debug  9000  34.212.183.107
# 35253   info  9000  34.212.183.107
# 35254  debug  9000  34.212.183.107
# 35255  debug  9000  34.212.183.107
#
#                                                   caller  \
# 0      /mnt/jenkins/workspace/harmony-release/harmony...
# 1      /mnt/jenkins/workspace/harmony-release/harmony...
# 2      /mnt/jenkins/workspace/harmony-release/harmony...
# 3      /mnt/jenkins/workspace/harmony-release/harmony...
# 4      /mnt/jenkins/workspace/harmony-release/harmony...
# ...                                                  ...
# 35251  /mnt/jenkins/workspace/harmony-release/harmony...
# 35252  /mnt/jenkins/workspace/harmony-release/harmony...
# 35253  /mnt/jenkins/workspace/harmony-release/harmony...
# 35254  /mnt/jenkins/workspace/harmony-release/harmony...
# 35255  /mnt/jenkins/workspace/harmony-release/harmony...
#
#                                      time  \
# 0     2020-04-13 19:59:54.552898738+00:00
# 1     2020-04-13 19:59:57.869071308+00:00
# 2     2020-04-13 19:59:59.554797544+00:00
# 3     2020-04-13 20:00:03.889666848+00:00
# 4     2020-04-13 20:00:06.042407845+00:00
# ...                                   ...
# 35251 2020-04-14 22:50:02.321966720+00:00
# 35252 2020-04-14 22:50:05.662677558+00:00
# 35253 2020-04-14 22:50:07.541041414+00:00
# 35254 2020-04-14 22:50:10.508881447+00:00
# 35255 2020-04-14 22:50:13.830171492+00:00
#
#                                        message  MsgBlockNum  MsgViewID
# 0      [OnCommitted] Receive committed message          NaN        NaN
# 1        [OnAnnounce] Receive announce message          NaN        NaN
# 2       [OnPrepared] Received prepared message    3032034.0  3032114.0
# 3      [OnCommitted] Receive committed message          NaN        NaN
# 4        [OnAnnounce] Receive announce message          NaN        NaN
# ...                                        ...          ...        ...
# 35251  [OnCommitted] Receive committed message          NaN        NaN
# 35252    [OnAnnounce] Receive announce message          NaN        NaN
# 35253   [OnPrepared] Received prepared message    3043784.0  3043864.0
# 35254  [OnCommitted] Receive committed message          NaN        NaN
# 35255    [OnAnnounce] Receive announce message          NaN        NaN
#
# [35256 rows x 8 columns]

# %%
df.iloc[1:-1].groupby('message')['message'].count()
# Out:
# message
# [OnAnnounce] Receive announce message      11751
# [OnCommitted] Receive committed message    11752
# [OnPrepared] Received prepared message     11751
# Name: message, dtype: int64

# %%
new_df = df.iloc[1:-1].reset_index(drop = True)
get_missing_msg_index(new_df)
# Out:
# 20919

# %%
new_df.iloc[20913:20923]
# Out:
#        level  port              ip  \
# 20913  debug  9000  34.212.183.107
# 20914   info  9000  34.212.183.107
# 20915  debug  9000  34.212.183.107
# 20916  debug  9000  34.212.183.107
# 20917  debug  9000  34.212.183.107
# 20918   info  9000  34.212.183.107
# 20919  debug  9000  34.212.183.107
# 20920  debug  9000  34.212.183.107
# 20921   info  9000  34.212.183.107
# 20922  debug  9000  34.212.183.107
#
#                                                   caller  \
# 20913  /mnt/jenkins/workspace/harmony-release/harmony...
# 20914  /mnt/jenkins/workspace/harmony-release/harmony...
# 20915  /mnt/jenkins/workspace/harmony-release/harmony...
# 20916  /mnt/jenkins/workspace/harmony-release/harmony...
# 20917  /mnt/jenkins/workspace/harmony-release/harmony...
# 20918  /mnt/jenkins/workspace/harmony-release/harmony...
# 20919  /mnt/jenkins/workspace/harmony-release/harmony...
# 20920  /mnt/jenkins/workspace/harmony-release/harmony...
# 20921  /mnt/jenkins/workspace/harmony-release/harmony...
# 20922  /mnt/jenkins/workspace/harmony-release/harmony...
#
#                                      time  \
# 20913 2020-04-14 11:55:15.470801024+00:00
# 20914 2020-04-14 11:55:17.291594236+00:00
# 20915 2020-04-14 11:55:20.210606584+00:00
# 20916 2020-04-14 11:55:28.767791848+00:00
# 20917 2020-04-14 11:55:30.211871748+00:00
# 20918 2020-04-14 11:55:30.642144377+00:00
# 20919 2020-04-14 11:55:35.260831481+00:00
# 20920 2020-04-14 11:55:36.988741509+00:00
# 20921 2020-04-14 11:55:38.781491088+00:00
# 20922 2020-04-14 11:55:41.876929946+00:00
#
#                                        message  MsgBlockNum  MsgViewID
# 20913    [OnAnnounce] Receive announce message          NaN        NaN
# 20914   [OnPrepared] Received prepared message    3039005.0  3039085.0
# 20915  [OnCommitted] Receive committed message          NaN        NaN
# 20916    [OnAnnounce] Receive announce message          NaN        NaN
# 20917  [OnCommitted] Receive committed message          NaN        NaN
# 20918   [OnPrepared] Received prepared message    3039006.0  3039086.0
# 20919  [OnCommitted] Receive committed message          NaN        NaN
# 20920    [OnAnnounce] Receive announce message          NaN        NaN
# 20921   [OnPrepared] Received prepared message    3039007.0  3039087.0
# 20922  [OnCommitted] Receive committed message          NaN        NaN
