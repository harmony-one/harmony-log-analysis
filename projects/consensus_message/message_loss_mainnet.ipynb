# %%
import json
import pandas as pd
import os
from os import path
import gzip
import re
import numpy as np

# %%
def read_data(files, log_dir, date):
    data = []
    for file in files:
        if date in file:
            with gzip.open(path.join(log_dir, file)) as f:
                for line in f.readlines():
                    if 'Received prepared message'.encode('utf-8') in line \
                    or 'Receive announce message'.encode('utf-8') in line\
                    or 'Receive committed message'.encode('utf-8') in line:
                        data.append(json.loads(line))
    return data

# %%
def data_processing(data):
    df = pd.DataFrame(data)
    df['time'] = pd.to_datetime(df['time'], format = '%Y-%m-%dT%H:%M:%S.%f')
    df.sort_values(by=['time','message'], inplace = True)
    while df.message.iloc[0] != '[OnAnnounce] Receive announce message':
        df = df[1:]
    while df.message.iloc[-1] != '[OnCommitted] Receive committed message':
        df = df[:-1]
    df.reset_index(inplace = True, drop = True)
    return df

# %%
def get_missing_msg_index(df):
    for name, group in df.groupby(df.index //3):
        if group.iloc[0]['message'] != '[OnAnnounce] Receive announce message':
            index = group.iloc[0].name
            break
    else:
        index = None
    return index

# %%
def getMissingMsgDf(nodes, date):
    announce = []
    commit = []
    prepare = []
    node = []
    time = []
    for i in range(len(nodes)):
        node.append(nodes[i])
        log = path.join(log_dir, nodes[i])
        files = os.listdir(log)
        try:
            data = read_data(files, log, date)
        except:
            print("can't read data", nodes[i])
        try:
            df = data_processing(data)
        except:
            print("can't process data", nodes[i])
        count = df.groupby('message')['message'].count()
        announce.append(count.iloc[0])
        commit.append(count.iloc[1])
        prepare.append(count.iloc[2])
        idx = get_missing_msg_index(df)
        if idx:
            time.append(df.iloc[idx].time)
        else:
            time.append(np.nan)

    col_name = count.index.tolist()
    col_name.insert(0, "node")
    col_name.append("missing-time")
    df = pd.DataFrame(list(zip(node, announce, prepare, commit, time)), columns = col_name)
    return df

# %%
log_dir = "/home/ubuntu/jupyter/logs/mainnet/"
nodes = os.listdir(log_dir)

# %%
getMissingMsgDf(nodes, '04-19')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11709
# 1   3.125.154.121                                  11762
# 2  34.251.240.119                                  11723
# 3    18.197.90.17                                   9409
# 4   3.121.218.212                                  11758
# 5     3.123.30.30                                   9424
# 6    34.218.48.95                                  11765
# 7  34.212.183.107                                   9378
# 8   54.212.72.201                                  11738
# 9   18.196.217.89                                   9418
#
#    [OnCommitted] Receive committed message  \
# 0                                    11709
# 1                                    11762
# 2                                    11723
# 3                                     9409
# 4                                    11758
# 5                                     9424
# 6                                    11765
# 7                                     9378
# 8                                    11738
# 9                                     9418
#
#    [OnPrepared] Received prepared message                        missing-time
# 0                                   11710 2020-04-19 01:48:16.717392020+00:00
# 1                                   11763 2020-04-19 01:48:16.720819820+00:00
# 2                                   11724 2020-04-19 01:48:16.717049459+00:00
# 3                                    9410 2020-04-19 01:48:16.727088057+00:00
# 4                                   11759 2020-04-19 01:48:16.721927202+00:00
# 5                                    9425 2020-04-19 01:48:16.720679307+00:00
# 6                                   11766 2020-04-19 01:48:16.654354897+00:00
# 7                                    9379 2020-04-19 01:48:16.654107326+00:00
# 8                                   11739 2020-04-19 01:48:16.655819992+00:00
# 9                                    9419 2020-04-19 01:48:16.721413364+00:00

# %%
getMissingMsgDf(nodes, '04-18')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                   9381
# 1   3.125.154.121                                   9414
# 2  34.251.240.119                                   9377
# 3    18.197.90.17                                  11779
# 4   3.121.218.212                                   9411
# 5     3.123.30.30                                  11788
# 6    34.218.48.95                                   9410
# 7  34.212.183.107                                  11743
# 8   54.212.72.201                                   9385
# 9   18.196.217.89                                   9420
#
#    [OnCommitted] Receive committed message  \
# 0                                     9381
# 1                                     9414
# 2                                     9377
# 3                                    11779
# 4                                     9411
# 5                                    11788
# 6                                     9410
# 7                                    11743
# 8                                     9385
# 9                                     9420
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                    9381           NaN
# 1                                    9414           NaN
# 2                                    9377           NaN
# 3                                   11779           NaN
# 4                                    9411           NaN
# 5                                   11788           NaN
# 6                                    9410           NaN
# 7                                   11743           NaN
# 8                                    9385           NaN
# 9                                    9420           NaN

# %%
getMissingMsgDf(nodes, '04-17')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11705
# 1   3.125.154.121                                  11780
# 2  34.251.240.119                                  11702
# 3    18.197.90.17                                   9424
# 4   3.121.218.212                                  11769
# 5     3.123.30.30                                   9424
# 6    34.218.48.95                                  11789
# 7  34.212.183.107                                   9396
# 8   54.212.72.201                                  11718
# 9   18.196.217.89                                  11799
#
#    [OnCommitted] Receive committed message  \
# 0                                    11705
# 1                                    11780
# 2                                    11702
# 3                                     9424
# 4                                    11769
# 5                                     9424
# 6                                    11789
# 7                                     9396
# 8                                    11718
# 9                                    11799
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                   11705           NaN
# 1                                   11780           NaN
# 2                                   11702           NaN
# 3                                    9424           NaN
# 4                                   11769           NaN
# 5                                    9424           NaN
# 6                                   11789           NaN
# 7                                    9396           NaN
# 8                                   11718           NaN
# 9                                   11799           NaN

# %%
getMissingMsgDf(nodes, '04-16')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                   9404
# 1   3.125.154.121                                   9430
# 2  34.251.240.119                                   9419
# 3    18.197.90.17                                   9449
# 4   3.121.218.212                                   9425
# 5     3.123.30.30                                  11826
# 6    34.218.48.95                                   9439
# 7  34.212.183.107                                  11760
# 8   54.212.72.201                                  11739
# 9   18.196.217.89                                   9426
#
#    [OnCommitted] Receive committed message  \
# 0                                     9404
# 1                                     9430
# 2                                     9419
# 3                                     9449
# 4                                     9425
# 5                                    11826
# 6                                     9439
# 7                                    11760
# 8                                    11739
# 9                                     9426
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                    9404           NaN
# 1                                    9430           NaN
# 2                                    9419           NaN
# 3                                    9449           NaN
# 4                                    9425           NaN
# 5                                   11826           NaN
# 6                                    9439           NaN
# 7                                   11760           NaN
# 8                                   11739           NaN
# 9                                    9426           NaN

# %%
getMissingMsgDf(nodes, '04-15')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11731
# 1   3.125.154.121                                  11759
# 2  34.251.240.119                                  11715
# 3    18.197.90.17                                  11785
# 4   3.121.218.212                                  11789
# 5     3.123.30.30                                   9427
# 6    34.218.48.95                                  11759
# 7  34.212.183.107                                   9389
# 8   54.212.72.201                                  11738
# 9   18.196.217.89                                  11768
#
#    [OnCommitted] Receive committed message  \
# 0                                    11731
# 1                                    11759
# 2                                    11715
# 3                                    11785
# 4                                    11789
# 5                                     9427
# 6                                    11759
# 7                                     9389
# 8                                    11738
# 9                                    11768
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                   11731           NaN
# 1                                   11759           NaN
# 2                                   11715           NaN
# 3                                   11785           NaN
# 4                                   11789           NaN
# 5                                    9427           NaN
# 6                                   11759           NaN
# 7                                    9389           NaN
# 8                                   11738           NaN
# 9                                   11768           NaN

# %%
getMissingMsgDf(nodes, '04-14')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                   9351
# 1   3.125.154.121                                   9401
# 2  34.251.240.119                                   9365
# 3    18.197.90.17                                   9418
# 4   3.121.218.212                                   9413
# 5     3.123.30.30                                  11792
# 6    34.218.48.95                                   9398
# 7  34.212.183.107                                  11751
# 8   54.212.72.201                                   9392
# 9   18.196.217.89                                   9412
#
#    [OnCommitted] Receive committed message  \
# 0                                     9351
# 1                                     9401
# 2                                     9365
# 3                                     9418
# 4                                     9413
# 5                                    11792
# 6                                     9398
# 7                                    11751
# 8                                     9392
# 9                                     9412
#
#    [OnPrepared] Received prepared message                        missing-time
# 0                                    9352 2020-04-14 11:55:35.323709096+00:00
# 1                                    9402 2020-04-14 11:55:35.332241283+00:00
# 2                                    9366 2020-04-14 11:55:35.323477151+00:00
# 3                                    9419 2020-04-14 11:55:35.336683209+00:00
# 4                                    9414 2020-04-14 11:55:35.331506851+00:00
# 5                                   11793 2020-04-14 11:55:35.331844929+00:00
# 6                                    9399 2020-04-14 11:55:35.260844611+00:00
# 7                                   11752 2020-04-14 11:55:35.260831481+00:00
# 8                                    9393 2020-04-14 11:55:35.260765168+00:00
# 9                                    9413 2020-04-14 11:55:35.332701592+00:00

# %%
getMissingMsgDf(nodes, '04-13')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11724
# 1   3.125.154.121                                  11789
# 2  34.251.240.119                                  11756
# 3    18.197.90.17                                  11792
# 4   3.121.218.212                                  11782
# 5     3.123.30.30                                   9445
# 6    34.218.48.95                                  11797
# 7  34.212.183.107                                   9401
# 8   54.212.72.201                                  11782
# 9   18.196.217.89                                  11766
#
#    [OnCommitted] Receive committed message  \
# 0                                    11724
# 1                                    11789
# 2                                    11756
# 3                                    11792
# 4                                    11782
# 5                                     9445
# 6                                    11797
# 7                                     9401
# 8                                    11782
# 9                                    11766
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                   11724           NaN
# 1                                   11789           NaN
# 2                                   11756           NaN
# 3                                   11792           NaN
# 4                                   11782           NaN
# 5                                    9445           NaN
# 6                                   11797           NaN
# 7                                    9401           NaN
# 8                                   11782           NaN
# 9                                   11766           NaN

# %%
getMissingMsgDf(nodes, '04-12')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11537
# 1   3.125.154.121                                   9431
# 2  34.251.240.119                                   9403
# 3    18.197.90.17                                   9426
# 4   3.121.218.212                                   9430
# 5     3.123.30.30                                  11816
# 6    34.218.48.95                                   9436
# 7  34.212.183.107                                  11768
# 8   54.212.72.201                                   9436
# 9   18.196.217.89                                   9409
#
#    [OnCommitted] Receive committed message  \
# 0                                    11537
# 1                                     9431
# 2                                     9403
# 3                                     9426
# 4                                     9430
# 5                                    11816
# 6                                     9436
# 7                                    11768
# 8                                     9436
# 9                                     9409
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                   11537           NaN
# 1                                    9431           NaN
# 2                                    9403           NaN
# 3                                    9426           NaN
# 4                                    9430           NaN
# 5                                   11816           NaN
# 6                                    9436           NaN
# 7                                   11768           NaN
# 8                                    9436           NaN
# 9                                    9409           NaN

# %%
getMissingMsgDf(nodes, '04-11')
# Out:
#              node  [OnAnnounce] Receive announce message  \
# 0  18.202.231.246                                  11747
# 1   3.125.154.121                                   9416
# 2  34.251.240.119                                  11727
# 3    18.197.90.17                                  11772
# 4   3.121.218.212                                  11796
# 5     3.123.30.30                                   9452
# 6    34.218.48.95                                   9407
# 7  34.212.183.107                                   9397
# 8   54.212.72.201                                  11770
# 9   18.196.217.89                                  11760
#
#    [OnCommitted] Receive committed message  \
# 0                                    11747
# 1                                     9416
# 2                                    11727
# 3                                    11772
# 4                                    11796
# 5                                     9452
# 6                                     9407
# 7                                     9397
# 8                                    11770
# 9                                    11760
#
#    [OnPrepared] Received prepared message  missing-time
# 0                                   11747           NaN
# 1                                    9416           NaN
# 2                                   11727           NaN
# 3                                   11772           NaN
# 4                                   11796           NaN
# 5                                    9452           NaN
# 6                                    9407           NaN
# 7                                    9397           NaN
# 8                                   11770           NaN
# 9                                   11760           NaN
