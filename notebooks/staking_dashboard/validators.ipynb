# %%
from pyhmy import cli
import json
import pandas as pd
import numpy as np
import os

# %%
env = cli.download()
cli.environment.update(env)
# Out:
# Saved harmony binary to: `/Users/yishuang/Desktop/log_analysis/notebooks/staking_dashboard/bin/hmy`

# %%
path = os.getcwd() + "/bin/hmy"
cli.set_binary(path)
# Out:
# True

# %%
validator = json.loads(cli.single_call("hmy --node=https://api.s0.os.hmny.io blockchain validator all"))['result']

# %%
shard = []
availability = []
name = []
epos_status = []
committee = []
website = []
details = []
address = []
for i in validator:  
    info = json.loads(cli.single_call("hmy --node=https://api.s0.os.hmny.io blockchain validator information " + i))['result']
    if not info['metrics']:
        shard.append(np.nan)
    else:
        shard.append(info['metrics']['by-shard'][0]['shard-id'])
    if not info['current-epoch-performance']:
        availability.append(np.nan)
    else:
        availability.append(info['current-epoch-performance']['current-epoch-signing-percent'])
    name.append(info['validator']['name'])
    epos_status.append(info['epos-status'])
    committee.append(info['currently-in-committee'])
    website.append(info['validator']['website'])
    details.append(info['validator']['details'])
    address.append(info['validator']['address'])

# %%
i = validator[0]
json.loads(cli.single_call("hmy --node=https://api.s0.os.hmny.io blockchain validator information " + i))['result']
# Out:
# {'current-epoch-performance': {'current-epoch-signing-percent': {'current-epoch-blocks-left': 21,
#    'current-epoch-signed': 17,
#    'current-epoch-signing-percentage': '1.000000000000000000',
#    'current-epoch-to-sign': 17}},
#  'currently-in-committee': True,
#  'epos-status': 'currently elected and signing enough blocks to be eligible for election next epoch',
#  'metrics': {'by-shard': [{'bls-public-key': 'afc4d81ab636323b04893c23d3404f38e95e9291b3d5299dade3d03822edd3a2b799bd6d64265a9a9cac025d5dbd600c',
#     'earning-account': 'one1m6j80t6rhc3ypaumtsfmqwjwp0mrqk9ff50prh',
#     'effective-stake': '15300000000000000000000.000000000000000000',
#     'group-percent': '0.149122807017543860',
#     'overall-percent': '0.047719298245614035',
#     'shard-id': 0}],
#   'current-apr': '0.000000000000000000',
#   'total-effective-stake': '15300000000000000000000.000000000000000000'},
#  'total-delegation': 9.99919e+21,
#  'validator': {'address': 'one1m6j80t6rhc3ypaumtsfmqwjwp0mrqk9ff50prh',
#   'bls-public-keys': ['afc4d81ab636323b04893c23d3404f38e95e9291b3d5299dade3d03822edd3a2b799bd6d64265a9a9cac025d5dbd600c'],
#   'creation-height': 304,
#   'delegations': [{'amount': 100000000000000000000,
#     'delegator-address': 'one1m6j80t6rhc3ypaumtsfmqwjwp0mrqk9ff50prh',
#     'reward': 7.640854098811683e+21,
#     'undelegations': []},
#    {'amount': 3190000000000000000,
#     'delegator-address': 'one1y5n7p8a845v96xyx2gh75wn5eyhtw5002lah27',
#     'reward': 57887376330632760000,
#     'undelegations': []},
#    {'amount': 9.896e+21,
#     'delegator-address': 'one1km7xg8e3xjys7azp9f4xp8hkw79vm2h3f2lade',
#     'reward': 2.0084237964720294e+22,
#     'undelegations': []}],
#   'details': 'OSTN Sentry for Shard 0',
#   'identity': 'OSTNSentry0',
#   'last-epoch-in-committee': 117,
#   'lifetime': {'blocks': {'signed': 4115, 'to-sign': 4120},
#    'reward-accumulated': 2.778297943986261e+22},
#   'max-change-rate': '0.020000000000000000',
#   'max-rate': '0.800000000000000000',
#   'max-total-delegation': 1e+22,
#   'min-self-delegation': 10000000000000000000,
#   'name': 'OSTNSentry0',
#   'rate': '0.050000000000000000',
#   'security-contact': 'Sentry',
#   'update-height': 304,
#   'website': 'sentry@harmony.one'}}

# %%
info
# Out:
# {'current-epoch-performance': None,
#  'currently-in-committee': False,
#  'epos-status': 'not eligible to be elected next epoch',
#  'metrics': None,
#  'total-delegation': 1e+22,
#  'validator': {'address': 'one1ma3l0kjrg4sn5n3k2e402dk4sgeye35gd8rs4u',
#   'bls-public-keys': ['42ac9ff51624f1b355fb3b6ac2158797c4293f5da8164767f60c7051740dc235b5b302f95f8c376ce86b2887b18ee188'],
#   'creation-height': 1888,
#   'delegations': [{'amount': 1e+22,
#     'delegator-address': 'one1ma3l0kjrg4sn5n3k2e402dk4sgeye35gd8rs4u',
#     'reward': 0,
#     'undelegations': []}],
#   'details': 's@harmony.one/3',
#   'identity': 's@harmony.one/3',
#   'last-epoch-in-committee': 50,
#   'lifetime': {'blocks': {'signed': 0, 'to-sign': 38},
#    'reward-accumulated': 0},
#   'max-change-rate': '0.100000000000000000',
#   'max-rate': '0.100000000000000000',
#   'max-total-delegation': 1e+24,
#   'min-self-delegation': 10000000000000000000,
#   'name': 's@harmony.one/3',
#   'rate': '0.100000000000000000',
#   'security-contact': 's@harmony.one/3',
#   'update-height': 1888,
#   'website': 's@harmony.one/3'}}

# %%
df = pd.DataFrame(list(zip(shard, availability, name, epos_status, committee, website, details, address)), \
                  columns =['shard-id', 'availability', 'name','epos-status', 'currently-in-committee', \
                            'website','details','address'])
# df = pd.concat([df.drop(['availability'], axis=1), df['availability'].apply(pd.Series)], axis=1)

# %%
df = pd.concat([df.drop(['availability'], axis=1), df['availability'].apply(pd.Series)], axis=1)

# %%
df.columns
# Out:
# Index([                        'shard-id',                             'name',
#                             'epos-status',           'currently-in-committee',
#                                 'website',                          'details',
#                                 'address',                                  0,
#               'current-epoch-blocks-left',             'current-epoch-signed',
#        'current-epoch-signing-percentage',            'current-epoch-to-sign'],
#       dtype='object')

# %%
df.drop([0], axis = 1, inplace = True)

# %%
df = df.sort_values(by=['shard-id'])
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#     shard-id                                           name  \
# 0        0.0                                    OSTNSentry0
# 1        0.0                                          MeiLi
# 2        0.0                                    Staking4All
# 3        0.0                                       WeAreONE
# 4        0.0                                     theRealONE
# 5        0.0  Crypto's Wolf Of All Streets #P-Ops <shard0>
# 6        1.0                                    “Maggie王艺格”
# 7        1.0                                    err0r_P-OPS
# 8        1.0                                  BigCryptoKing
# 9        1.0                                       teahouse
# 10       1.0                                s@harmony.one/2
# 11       1.0                            MirrorMirage P-OPS
# 12       2.0                                        Niteesh
# 13       2.0                  Bruno Marshall #pops <Shard2>
# 14       2.0                       JB273-OpenStaking #P-OPS
# 15       2.0                                         leo130
# 16       2.0                                    mind #P-OPS
# 17       2.0                                    OSTNSentry2
# 18       2.0                                        C7Stake
# 19       3.0                                           Vega
# 20       3.0                                     SahildeONE
# 21       3.0                                         Ganesh
# 22       3.0                                     Sesameseed
# 23       3.0                          harmony_sentry_359481
# 24       NaN                                    OSTNSentry1
# 25       NaN                                    OSTNSentry3
# 26       NaN                                            Cem
# 27       NaN                                   JSK_ONE_NODE
# 28       NaN                                          Gordo
# 29       NaN                                         Catana
# 30       NaN                                   ChainodeTech
# 31       NaN                                       OgreNode
# 32       NaN                                  s@harmony.one
# 33       NaN                                        dillagr
# 34       NaN                                           Dave
# 35       NaN                                         gondar
# 36       NaN                                Sirens Of Titan
# 37       NaN                                          iBriz
# 38       NaN                                     sagekn1ght
# 39       NaN                                         Marco2
# 40       NaN                                s@harmony.one/3
#
#                                           epos-status  currently-in-committee  \
# 0   currently elected and signing enough blocks to...                    True
# 1   currently elected and signing enough blocks to...                    True
# 2   currently elected and signing enough blocks to...                    True
# 3   currently elected and signing enough blocks to...                    True
# 4   currently elected and signing enough blocks to...                    True
# 5   currently elected and signing enough blocks to...                    True
# 6   currently elected and signing enough blocks to...                    True
# 7   currently elected and signing enough blocks to...                    True
# 8   currently elected and signing enough blocks to...                    True
# 9   currently elected and signing enough blocks to...                    True
# 10  currently elected and signing enough blocks to...                    True
# 11  currently elected and signing enough blocks to...                    True
# 12  currently elected and signing enough blocks to...                    True
# 13  currently elected and signing enough blocks to...                    True
# 14  currently elected and signing enough blocks to...                    True
# 15  currently elected and signing enough blocks to...                    True
# 16  currently elected and signing enough blocks to...                    True
# 17  currently elected and signing enough blocks to...                    True
# 18  currently elected and signing enough blocks to...                    True
# 19  currently elected and signing enough blocks to...                    True
# 20  currently elected and signing enough blocks to...                    True
# 21  currently elected and signing enough blocks to...                    True
# 22  currently elected and signing enough blocks to...                    True
# 23  currently elected and signing enough blocks to...                    True
# 24              not eligible to be elected next epoch                   False
# 25              not eligible to be elected next epoch                   False
# 26              not eligible to be elected next epoch                   False
# 27              not eligible to be elected next epoch                   False
# 28              not eligible to be elected next epoch                   False
# 29              not eligible to be elected next epoch                   False
# 30              not eligible to be elected next epoch                   False
# 31              not eligible to be elected next epoch                   False
# 32              not eligible to be elected next epoch                   False
# 33              not eligible to be elected next epoch                   False
# 34              not eligible to be elected next epoch                   False
# 35              not eligible to be elected next epoch                   False
# 36              not eligible to be elected next epoch                   False
# 37              not eligible to be elected next epoch                   False
# 38              not eligible to be elected next epoch                   False
# 39              not eligible to be elected next epoch                   False
# 40              not eligible to be elected next epoch                   False
#
#                                            website  \
# 0                               sentry@harmony.one
# 1                                   li@harmony.one
# 2                          https://staking4all.org
# 3                                     AKC12190.COM
# 4                                               NA
# 5                           CryptoWolf@harmony.one
# 6                                 YOUR-WEBSITE.COM
# 7                                err0r@harmony.one
# 8                https://twitter.com/BigCryptoKing
# 9                        https://teemaja.github.io
# 10                                 s@harmony.one/2
# 11                       mirrormirage0@harmony.one
# 12                             Niteesh@harmony.one
# 13      https://store.cdbaby.com/cd/brunomarshall3
# 14                               JB273.harmony.one
# 15                     https://staking.leochen.net
# 16                                mind@harmony.one
# 17                              sentry@harmony.one
# 18                              mrbubz@harmony.one
# 19  https://giphy.com/gifs/rick-roll-lgcUUCXgC8mEo
# 20                               sahil@harmony.one
# 21                              ganesh@harmony.one
# 22                         https://sesameseed.org/
# 23                                     harmony.one
# 24                              sentry@harmony.one
# 25                              sentry@harmony.one
# 26                                 cem@harmony.one
# 27
# 28                                        gordo.pt
# 29                                onevalidator.com
# 30                                   chainode.tech
# 31                                         NAW.com
# 32                                   s@harmony.one
# 33                           http://bit.ly/dillagr
# 34                       harmony.one/pomptooneeuro
# 35                                      github.com
# 36            https://twitter.com/@GlennBe55899459
# 37                                harmony@ibriz.ai
# 38                          sagekn1ght.harmony.one
# 39                               marco@harmony.one
# 40                                 s@harmony.one/3
#
#                                               details  \
# 0                             OSTN Sentry for Shard 0
# 1                                    Li The Validator
# 2   Validator for Proof of Stake blockchains. Dele...
# 3                                        AKCValidator
# 4                             @BaJaSam validator node
# 5                      CryptoWolfs Validation Station
# 6                                             DETAILS
# 7                                           T = Wb/m²
# 8                                          Stake Here
# 9                                               first
# 10                                    s@harmony.one/2
# 11                                      mirrormirage0
# 12                                            Niteesh
# 13                        BrunoMarshall the validator
# 14                 OpenStaking made possible by JB273
# 15       Amazon Veteran with strong DevOps experience
# 16                             pink pony node runners
# 17                            OSTN Sentry for Shard 2
# 18                             C7Stake EPoS Validator
# 19                                  Cheap Stake here
# 20                                Sahil The Validator
# 21                               Ganesh the validator
# 22  Sesameseed is a multi-chain digital asset stak...
# 23                                               none
# 24                            OSTN Sentry for Shard 1
# 25                            OSTN Sentry for Shard 3
# 26                                            The Cem
# 27                         JSK ONE node running local
# 28                                   Gordo validating
# 29                                           SoftNode
# 30  ChainodeTech is your reliable partner for dist...
# 31                                         OgreAbroad
# 32                                      s@harmony.one
# 33                                            MrRobot
# 34                 I ONCE AGAIN ASKING TO DELEGATE ME
# 35                                      Bounty Hunter
# 36                     Chrono Synclastic Infundibulum
# 37                                iBriz The Validator
# 38                                           SageNode
# 39                                Marco the Validator
# 40                                    s@harmony.one/3
#
#                                        address  current-epoch-blocks-left  \
# 0   one1m6j80t6rhc3ypaumtsfmqwjwp0mrqk9ff50prh                       37.0
# 1   one1p5hv9qv90dyrag9fj3wzrvvrs273ypcq8mz7zn                       35.0
# 2   one1dcmp24uqgwszcvmm8n6r5dvhqhuukdj86pkg6n                       37.0
# 3   one17tj2jjehdlg8xfgp48xpeyqur2qf6nvs88jvyu                       36.0
# 4   one1ekup98s5tqxtr5hdzsz664cfy579jpq6w5smrr                       36.0
# 5   one10jvjrtwpz2sux2ngktg3kq7m3sdz5p5au5l8c8                       36.0
# 6   one1j33qtvx86j4ugy0a8exwwhtldm5wv4daksrwsl                       34.0
# 7   one1c9h3u72czs6sk755tjyse7x5t70m38ppnkx922                       34.0
# 8   one1jjq5pl4le0fhhu3n2znkkt9tydrzjcyzaljtnl                       35.0
# 9   one1k9577lnpfx7z76zslc6r8gdmsp5kqgpll7cpk9                       35.0
# 10  one1ujljr2nuymtxm0thjm32f64xsa9uzs54swreyw                       35.0
# 11  one1vfqqagdzz352mtvdl69v0hw953hm993n6v26yl                       37.0
# 12  one10qq0uqa4gvgdufqjph89pp7nj6yeatz94xdjrt                       36.0
# 13  one1km7xg8e3xjys7azp9f4xp8hkw79vm2h3f2lade                       37.0
# 14  one1gjsxmewzws9mt3fn65jmdhr3e4hel9xza8wd6t                       36.0
# 15  one18vn078vyp5jafma8q7kek6w0resrgex9yufqws                       37.0
# 16  one1s7fp0jrmd97estwye3mhkp7xsqf42vn5x2sfqy                       35.0
# 17  one1vzsj3julf0ljcj3hhxuqpu6zvadu488zfrtttz                       37.0
# 18  one1rhkl7c0jz09c9ffp2pncyr4uwamfpmcr83ufkr                       36.0
# 19  one1wz9fmjrwua3le0c8qxv058p3wpdg4ctjyc3ha4                       35.0
# 20  one1egemh5e9xjy3x8d3cq0kq7mw4sw4jjwgkc7axs                       36.0
# 21  one1tpxl87y4g8ecsm6ceqay49qxyl5vs94jjyfvd9                       36.0
# 22  one1a8avzz3hcvhfrh2tp7rdprpvwt838y9um9c2q7                       35.0
# 23  one1570ghhly80c5u0e48fyevus7uwzjl600zpghud                       38.0
# 24  one10fjqteq6q75nm62cx8vejqsk7mc8t5hle8ewnl                        NaN
# 25  one1marnnvc8hywmfxhrc8mtpjkvvdt32x9kxtwkvv                        NaN
# 26  one1tewvfjk0d4whmajpqvcvzfpx6wftrh0gagsa7n                        NaN
# 27  one1gm8xwupd9e77ja46eaxv8tk4ea7re5zknaauvq                        NaN
# 28  one1mpzx5wr2kmz9nvkhsgj6jr6zs87ahm0gxmhlck                        NaN
# 29  one19cuygr776f7j9ep97hjm0np9ay6nus9w5msy0n                        NaN
# 30  one1la07f5wduc3379ffzlpqrl4rcvlchyvtwf3uyj                        NaN
# 31  one1leh5rmuclw5u68gw07d86kqxjd69zuny3h23c3                        NaN
# 32  one1kvfsza4u4e5ml6qv92j2pmsal2am9mcv9u4g83                        NaN
# 33  one17d60e5nvjnzechwl56y38ze6w49wejhtanncra                        NaN
# 34  one14shlkfq00yfmf3r4gglt0hqfcxrgx7ysmsz832                        NaN
# 35  one1hpxxxnqp5epvs2ktzdft24q39r4pttywkmt3cy                        NaN
# 36  one1c42kf0tvgkh8ez4nfs2a8l7a7c4x53xqmh793c                        NaN
# 37  one1jm28f73rmg7lnca7duuyuqrhkp4ahfzdvzzdsf                        NaN
# 38  one1u0sa36a28dq4fufc9vs9hlnkjsrxr9k67w5ysu                        NaN
# 39  one1uvt0yl7dxyt9rh37gzm49vy3pgf0c3aud4k5p5                        NaN
# 40  one1ma3l0kjrg4sn5n3k2e402dk4sgeye35gd8rs4u                        NaN
#
#     current-epoch-signed current-epoch-signing-percentage  \
# 0                    1.0             1.000000000000000000
# 1                    3.0             1.000000000000000000
# 2                    1.0             1.000000000000000000
# 3                    2.0             1.000000000000000000
# 4                    2.0             1.000000000000000000
# 5                    2.0             1.000000000000000000
# 6                    4.0             1.000000000000000000
# 7                    4.0             1.000000000000000000
# 8                    3.0             1.000000000000000000
# 9                    3.0             1.000000000000000000
# 10                   3.0             1.000000000000000000
# 11                   1.0             1.000000000000000000
# 12                   2.0             1.000000000000000000
# 13                   1.0             1.000000000000000000
# 14                   2.0             1.000000000000000000
# 15                   1.0             1.000000000000000000
# 16                   3.0             1.000000000000000000
# 17                   1.0             1.000000000000000000
# 18                   2.0             1.000000000000000000
# 19                   3.0             1.000000000000000000
# 20                   2.0             1.000000000000000000
# 21                   2.0             1.000000000000000000
# 22                   3.0             1.000000000000000000
# 23                   0.0             0.000000000000000000
# 24                   NaN                              NaN
# 25                   NaN                              NaN
# 26                   NaN                              NaN
# 27                   NaN                              NaN
# 28                   NaN                              NaN
# 29                   NaN                              NaN
# 30                   NaN                              NaN
# 31                   NaN                              NaN
# 32                   NaN                              NaN
# 33                   NaN                              NaN
# 34                   NaN                              NaN
# 35                   NaN                              NaN
# 36                   NaN                              NaN
# 37                   NaN                              NaN
# 38                   NaN                              NaN
# 39                   NaN                              NaN
# 40                   NaN                              NaN
#
#     current-epoch-to-sign
# 0                     1.0
# 1                     3.0
# 2                     1.0
# 3                     2.0
# 4                     2.0
# 5                     2.0
# 6                     4.0
# 7                     4.0
# 8                     3.0
# 9                     3.0
# 10                    3.0
# 11                    1.0
# 12                    2.0
# 13                    1.0
# 14                    2.0
# 15                    1.0
# 16                    3.0
# 17                    1.0
# 18                    2.0
# 19                    3.0
# 20                    2.0
# 21                    2.0
# 22                    3.0
# 23                    0.0
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32                    NaN
# 33                    NaN
# 34                    NaN
# 35                    NaN
# 36                    NaN
# 37                    NaN
# 38                    NaN
# 39                    NaN
# 40                    NaN

# %%
df.to_csv("../../csv/validator.tsv", index=False)
