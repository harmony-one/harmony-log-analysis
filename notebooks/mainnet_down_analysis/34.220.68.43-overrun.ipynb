# %%
import json
import pandas as pd
import os
import shutil
import re
import plotly.express as px 
import plotly.graph_objects as go
import numpy as np
from IPython.core.display import display, HTML

# %%
def read_data(files, path, keyword):
    data = []
    for file in files:
        if "zerolog" in file:
            with open(path + file, errors='ignore') as f:
                for line in f.readlines():
                    if keyword in line:
                        data.append(json.loads(line))
    return data

# %%
def data_processing(data):
    df = pd.DataFrame(data)
    df['time'] = pd.to_datetime(df['time'], format = '%Y-%m-%dT%H:%M:%S.%f')
    return df

# %%
def aggregate(df, time, name):
    agg = df.groupby([pd.Grouper(freq= str(time) + 'Min', key = 'time'), name])[name].count().\
    reset_index(name = 'count')
    return agg

# %%
def get_top_frequent(df, name, number):
    sort_df = df.sort_values(by='count', ascending = False).reset_index(drop = True) 
    lst = sort_df.loc[:number, name].tolist()
    return lst

# %%
def draw_error(df, alert, viewchange, time, name):
    
    df = df.sort_values(by='time').reset_index(drop = True)
    html_path = "https://harmony-one.github.io/harmony-log-analysis/" + html_dir.replace("../../docs/", "") + name + ".html"
    png_path = fig_dir 
    print("png graphs saved in " + png_path)
    print('html graphs saved in ')
    display(HTML("<a href='" + html_path + "' target='_blank'>" + html_path + "</a>"))
    if not os.path.exists(html_dir):
        os.makedirs(html_dir)
        
    if not os.path.exists(png_path):
        os.makedirs(png_path)
    
    hover = df.columns.tolist()
    fig = px.line(df, x="time", y="count", color=name, color_discrete_sequence=px.colors.qualitative.Set2, \
              title = name + ' counts in ' + str(time) + ' minutes vs Time', hover_data=hover)
    fig.update_layout(xaxis_title="utc_time", legend_orientation="h", legend=dict(x=-0.05, y=-0.6))
    
    trace = []
    text = []
    for k,v in alert.items():
        fig.add_shape(type="line", x0=k, y0=0,x1=k,y1=1,
                line=dict(
                width=0.5,
            ))
        trace.append(k)
        text.append(v)
    
    
    for i in range(len(viewchange)):
        if viewchange.message[i] == 'NewView':
            fig.add_shape(type="line", x0=viewchange.time[i], y0=0,x1=viewchange.time[i],y1=1,
                    line=dict(
                    width=0.5,
                    color="LightSeaGreen",    

                ))

        if viewchange.message[i] == 'StartViewChange':
            fig.add_shape(type="line", x0=viewchange.time[i], y0=0,x1=viewchange.time[i],y1=1,
                    line=dict(
                    width=0.5,
                    dash="dashdot",
                    color="MediumPurple",    
                    ))
            
        if viewchange.message[i] == 'ResetViewChange':
            fig.add_shape(type="line", x0=viewchange.time[i], y0=0,x1=viewchange.time[i],y1=1,
                    line=dict(
                    width=0.5,
                    dash="longdash",
                    color="RoyalBlue",    
                    ),
                    opacity=0.5)
    
    fig.update_shapes(dict(xref='x', yref='paper'))
    
    newView = viewchange[viewchange.message == 'NewView'].iloc[0]
    startChange = viewchange[viewchange.message == 'StartViewChange'].iloc[0]
    resetChange = viewchange[viewchange.message == 'ResetViewChange'].iloc[0]
    lst = [startChange, newView, resetChange]

    for i in range(len(lst)):
        trace.insert(0, lst[i].time)
        text.insert(0, lst[i].message)
              
    fig.add_trace(go.Scatter(
        x=trace,
        y=np.linspace(df['count'].min()*1.2, df['count'].max()*0.9, num = len(text)).tolist(),
        text=text,
        mode="text",
        showlegend=False
    ))
    

    fig.show()
    fig.write_html(html_dir + name + ".html")
    fig.write_image(png_path + name + ".png",width=1000, height=600)

# %%
# get alert time from pagerduty
alert = dict()
alert['2020-03-31 11:24:18.0'] = 'Shard 0 stuck!'
alert['2020-03-31 11:16:47.0'] = 'Shard 2 stuck!'
alert['2020-03-31 07:15:15.0'] = 'Shard 3 stuck!'
alert['2020-03-31 07:15:24.0'] = 'Shard 1 stuck!'
alert['2020-03-30 20:52:40.0'] = 'Shard 0 stuck!'
alert['2020-03-30 20:52:32.0'] = 'Shard 2 stuck!'
alert['2020-03-30 20:52:37.0'] = 'Shard 3 stuck!'
alert['2020-03-30 20:52:31.0'] = 'Shard 1 stuck!'

# %%
log_dir = "/home/ubuntu/jupyter/logs/debug/20200331/shard3/leader/"
html_dir = "../../docs/graphs/crash_analysis/03-31/shard3/"
fig_dir = "../../graphs/crash_analysis/03-31/shard3/"
files = os.listdir(log_dir)

# %% [markdown]
# ### get the top sender

# %% [markdown]
# some metrics
# - total 124 different senders
# - max: 9428
# - min: 24
# - \> 9000 errors: 44 senders
# - \> 8000 errors: 51 senders
# - \> 5000 errors: 52 senders
# - \> 3000 errors: 113 senders

# %%
data = read_data(files, log_dir, 'overrun')
df = data_processing(data)
sender = df.groupby('sender')['sender'].count().reset_index(name = 'count') 
sender.sort_values(by='count', ascending = False).reset_index(drop = True)
# Out:
#                                              sender  count
# 0    Qmea5pZ4vwEbsVTob92sLeg9SQk5o91pR7bU67x9VzbkWU   9248
# 1    QmQQE4eWgW79vN8pLzznRNdHRRi6nWZ4RL352S6xJCSeu1   9248
# 2    QmZft5PhMxZoQx1sczcXtSt2tD4bFhjLCQWSoQPzTbz5GX   9248
# 3    QmdB3AhjX9snFsynMkp53VgE8tEnqztcbBN8fS5S9jhwGd   9248
# 4    Qmcxvs5mcDHu5S83t8Z1JqztPVsP2AzzusYy7U2GfHdgmF   9248
# ..                                              ...    ...
# 119  QmfAvzBRz2SppA5ozxw1nPfgqzAZQfVBTphvrJYqP9kTxN   1182
# 120  Qmc1ooNobR9uq7RZkGpfQGSeJB2fZCHSUHXfkrSpzaDH7G    815
# 121  QmY5LbbKPTKtbWY9HLcQ7AF3LU6tU5M3pM75vinQw3qjCZ    503
# 122  QmWHHRUTojdTFEGDi2thDpNVXbs5PiLvnyAAsHZ6RHraZe     58
# 123  QmaeVBBVMjR4SsRXxF8JQgwwwDJYxNJbJTGfhaZKWsxox9     24
#
# [124 rows x 2 columns]

# %%
sender.describe()
# Out:
#              count
# count   124.000000
# mean   5474.717742
# std    3157.392082
# min      24.000000
# 25%    3081.000000
# 50%    3086.000000
# 75%    9231.500000
# max    9248.000000

# %%
lst = get_top_frequent(sender, 'sender', 51)
mask = df['sender'].apply(lambda x: x in lst)
df_2 = df[mask]

# %% [markdown]
# ### add view change time

# %%
data = read_data(files, log_dir, 'start view change timer')
startViewChange = data_processing(data)[['time','message']]
startViewChange['message'] = 'StartViewChange'

data = read_data(files, log_dir, 'Resetting view change state')
resetViewChange = data_processing(data)[['time','message']]
resetViewChange['message'] = 'ResetViewChange'

data = read_data(files, log_dir, 'Received NewView Message')
newview = data_processing(data)[['time','message']]
newview['message'] = 'NewView'

viewchange = pd.concat([startViewChange, resetViewChange, newview], ignore_index=True)

# %% [markdown]
# ### aggregate on five minutes level

# %%
agg = aggregate(df_2, 5, 'sender')
agg.sort_values(by='count', ascending = False).reset_index(drop = True)
# Out:
#                           time  \
# 0    2020-03-31 01:00:00+00:00
# 1    2020-03-31 01:00:00+00:00
# 2    2020-03-31 01:00:00+00:00
# 3    2020-03-31 01:00:00+00:00
# 4    2020-03-31 01:00:00+00:00
# ...                        ...
# 3271 2020-03-31 06:20:00+00:00
# 3272 2020-03-31 06:20:00+00:00
# 3273 2020-03-31 06:20:00+00:00
# 3274 2020-03-31 06:20:00+00:00
# 3275 2020-03-31 06:20:00+00:00
#
#                                               sender  count
# 0     QmVKuF9RXEVUTcpQfLcdExFNgxaza22pXYG4tKGr59E4V4    156
# 1     QmWRqGxAch41er8JzC8jCLvEj6rfYz2pSbTrcyJhmko7no    156
# 2     QmVDPrtuHFG2WAkQVLRXQGEmQbx8FwhTY8LvM3ahbNqYhD    156
# 3     QmV8KyKF75E9FqRMnWrBGJPqHeqhxTZXAtHSe4k4iikZAP    156
# 4     QmV33UgvrQ5jf7Uhy4tjPD1rDZSXEuCb7YqeMqReUe74tr    156
# ...                                              ...    ...
# 3271  QmXaWMJYCuukwbazGr7RLUvFs9gAYG7LN74hLgWdSWUpyV     15
# 3272  QmXxdd5WcSS8DJMyGtP7a8S6vd9mgwNpxTSbsUJtF2N7WY     15
# 3273  QmZbMzrZexEZax44GSxAdKHEdcQgotm6K4Tu8X5qbWNBR1     15
# 3274  QmfMKDCBM7T8eNsX6KmfsurWUQtef3VdBM2vcXh8BAAGYa     15
# 3275  QmPmzUNMPuj3bkVzpAZWUZnJvLCZtBxdnSqjM9uX4rZbQf     10
#
# [3276 rows x 3 columns]

# %% [markdown]
# ### draw graphs

# %%
draw_error(agg, dict(list(alert.items())[0: 4]), viewchange, 5, 'sender')
# Out:
# png graphs saved in ../../graphs/crash_analysis/03-31/shard3/
# html graphs saved in
# <a href='https://harmony-one.github.io/harmony-log-analysis/graphs/crash_analysis/03-31/shard3/sender.html' target='_blank'>https://harmony-one.github.io/harmony-log-analysis/graphs/crash_analysis/03-31/shard3/sender.html</a>
# <div>
#
#
#             <div id="739c0cd1-1248-42d0-9894-b3c33bea6259" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("739c0cd1-1248-42d0-9894-b3c33bea6259")) {
#                     Plotly.newPlot(
#                         '739c0cd1-1248-42d0-9894-b3c33bea6259',
#                         [{"customdata": [[1585616100000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 144], [1585616400000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 156], [1585616700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585617000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585617300000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585617600000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585617900000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585618200000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585618500000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585618800000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585619100000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 151], [1585619400000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585619700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585620000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585620300000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585620600000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 141], [1585620900000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585621200000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585621500000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585621800000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 152], [1585622100000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 144], [1585622400000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585622700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 148], [1585623000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585623300000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 144], [1585623600000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585623900000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 144], [1585624200000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 144], [1585624500000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585624800000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585625100000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585625400000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585625700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585626000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585626300000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 154], [1585626600000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585626900000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585627200000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585627500000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585627800000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585628100000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585628400000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585628700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 150], [1585629000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585629300000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 153], [1585629600000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585629900000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 148], [1585630200000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 147], [1585630500000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 138], [1585631700000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TAWXjWShKHG", 38], [1585632000000000000, "QmNn7YtPELpRR67n2286YvjGhKvcoaqErr5TA ...
